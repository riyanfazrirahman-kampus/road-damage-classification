# %%
import os
import re
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from collections import Counter

from sklearn.metrics import classification_report, confusion_matrix

# %%
# ==========================================
# STEP 0: PARAMETERS & PATHS (sesuaikan)
# ==========================================
PROCESSED_DIR = "../dataset_processed_aug"  # output: train/ val/ test/ per kelas
MODEL_DIR = "../models"
MODEL_ID = 2

IMG_SIZE = (224, 224)   # tuple: target_size untuk flow_from_directory
IMG_SIDE = IMG_SIZE[0]  # integer untuk fungsi make_square
BATCH_SIZE = 32

# Training
TRAIN_EPOCHS = 30
TRAIN_DROPOUT = 0
TRAIN_LEARNING_RATE = 0.001

os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# ==========================================
# TABEL HORIZONTAL
# ==========================================
params = {
    "MODEL": MODEL_ID,
    "LEARNING_RATE": TRAIN_LEARNING_RATE,
    "BATCH": BATCH_SIZE,
    "EPOCHS": TRAIN_EPOCHS,
    "DROPOUT": TRAIN_DROPOUT,
    "AUGMENTASI": False
}

pd.DataFrame([params])
# Out:
#    MODEL  LEARNING_RATE  BATCH  EPOCHS  DROPOUT  AUGMENTASI
# 0      2          0.001     32      30        0       False

# %%
# ==========================================
# STEP 4: Data generators
# - train: augmentation + rescale
# - val/test: hanya rescale
# ==========================================

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)

valtest_datagen = ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
)

val_generator = valtest_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "val"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = valtest_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "test"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 3429 images belonging to 4 classes.
# Found 228 images belonging to 4 classes.
# Found 218 images belonging to 4 classes.

# %%
print("Generators siap:")
print(" - train samples:", train_generator.samples)
print(" - val samples:", val_generator.samples)
print(" - test samples:", test_generator.samples)
print("Classes:", train_generator.class_indices)

X_batch, Y_batch = next(train_generator)

print(X_batch.shape)  
print(Y_batch.shape)  # contoh: (32, jumlah_kelas)
print(Y_batch[0])     # label one-hot gambar pertama
# Out:
# Generators siap:
#  - train samples: 3429
#  - val samples: 228
#  - test samples: 218
# Classes: {'alur': 0, 'lubang': 1, 'retak': 2, 'tidak_rusak': 3}
# (32, 224, 224, 3)
# (32, 4)
# [0. 0. 1. 0.]

# %%
# ==========================================
# (Optional) print counts per class for sanity check
# ==========================================

print("\nCounts per class (train):")
train_counts = Counter([os.path.split(f)[0] for f in train_generator.filenames])
for cls, idx in train_generator.class_indices.items():
    print(f" - {cls}: {train_counts[cls]}")

print("\nCounts per class (val):")
val_counts = Counter([os.path.split(f)[0] for f in val_generator.filenames])
for cls, idx in val_generator.class_indices.items():
    print(f" - {cls}: {val_counts[cls]}")

print("\nCounts per class (test):")
val_counts = Counter([os.path.split(f)[0] for f in test_generator.filenames])
for cls, idx in val_generator.class_indices.items():
    print(f" - {cls}: {val_counts[cls]}")
# Out:
# Counts per class (train):
#  - alur: 857
#  - lubang: 858
#  - retak: 857
#  - tidak_rusak: 857
#
# Counts per class (val):
#  - alur: 5
#  - lubang: 116
#  - retak: 93
#  - tidak_rusak: 14
#
# Counts per class (test):
#  - alur: 6
#  - lubang: 112
#  - retak: 90
#  - tidak_rusak: 10

# %%
# ==========================================
# STEP 5: Build model (MobileNetV2 transfer learning)
# ==========================================

num_classes = train_generator.num_classes

MODEL_NAME = "MobileNetV2"
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIDE, IMG_SIDE, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(TRAIN_DROPOUT)(x)
preds = Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=preds)

# freeze base
for layer in base_model.layers:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=TRAIN_LEARNING_RATE), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

print("\nModel siap. Jumlah kelas:", num_classes)
# Out:
# Model siap. Jumlah kelas: 4

# %%
# ==========================================
# STEP 6: Callbacks 
# ==========================================

checkpoint_path = os.path.join(MODEL_DIR, "best_model2.h5")
callbacks = [
    ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_loss', verbose=1),
    EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
]

# %%
# ==========================================
# STEP 7: Training
# ==========================================

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=TRAIN_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 108/108 [==============================] - ETA: 0s - loss: 0.6554 - accuracy: 0.7559
# Epoch 1: val_loss improved from inf to 0.34986, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 86s 729ms/step - loss: 0.6554 - accuracy: 0.7559 - val_loss: 0.3499 - val_accuracy: 0.9035 - lr: 0.0010
# Epoch 2/30
# 108/108 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8959
# Epoch 2: val_loss improved from 0.34986 to 0.24832, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 38s 349ms/step - loss: 0.3397 - accuracy: 0.8959 - val_loss: 0.2483 - val_accuracy: 0.9079 - lr: 0.0010
# Epoch 3/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.9113
# Epoch 3: val_loss improved from 0.24832 to 0.23934, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 37s 343ms/step - loss: 0.2764 - accuracy: 0.9113 - val_loss: 0.2393 - val_accuracy: 0.9211 - lr: 0.0010
# Epoch 4/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.9213
# Epoch 4: val_loss improved from 0.23934 to 0.21060, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 37s 347ms/step - loss: 0.2433 - accuracy: 0.9213 - val_loss: 0.2106 - val_accuracy: 0.9342 - lr: 0.0010
# Epoch 5/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9323
# Epoch 5: val_loss improved from 0.21060 to 0.18111, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 35s 321ms/step - loss: 0.2131 - accuracy: 0.9323 - val_loss: 0.1811 - val_accuracy: 0.9430 - lr: 0.0010
# Epoch 6/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9402
# Epoch 6: val_loss improved from 0.18111 to 0.16975, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 47s 439ms/step - loss: 0.1907 - accuracy: 0.9402 - val_loss: 0.1698 - val_accuracy: 0.9474 - lr: 0.0010
# Epoch 7/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1840 - accuracy: 0.9423
# Epoch 7: val_loss did not improve from 0.16975
# 108/108 [==============================] - 45s 416ms/step - loss: 0.1840 - accuracy: 0.9423 - val_loss: 0.1921 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 8/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9455
# Epoch 8: val_loss did not improve from 0.16975
# 108/108 [==============================] - 47s 430ms/step - loss: 0.1716 - accuracy: 0.9455 - val_loss: 0.1794 - val_accuracy: 0.9561 - lr: 0.0010
# Epoch 9/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1629 - accuracy: 0.9504
# Epoch 9: val_loss did not improve from 0.16975
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 108/108 [==============================] - 46s 431ms/step - loss: 0.1629 - accuracy: 0.9504 - val_loss: 0.1827 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 10/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9533
# Epoch 10: val_loss did not improve from 0.16975
# 108/108 [==============================] - 44s 407ms/step - loss: 0.1495 - accuracy: 0.9533 - val_loss: 0.1787 - val_accuracy: 0.9474 - lr: 5.0000e-04
# Epoch 11/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9565
# Epoch 11: val_loss improved from 0.16975 to 0.16550, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 51s 472ms/step - loss: 0.1469 - accuracy: 0.9565 - val_loss: 0.1655 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 12/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9530
# Epoch 12: val_loss improved from 0.16550 to 0.16062, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 50s 460ms/step - loss: 0.1471 - accuracy: 0.9530 - val_loss: 0.1606 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 13/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9633
# Epoch 13: val_loss improved from 0.16062 to 0.15866, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 49s 458ms/step - loss: 0.1359 - accuracy: 0.9633 - val_loss: 0.1587 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 14/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9548
# Epoch 14: val_loss improved from 0.15866 to 0.15045, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 50s 459ms/step - loss: 0.1396 - accuracy: 0.9548 - val_loss: 0.1504 - val_accuracy: 0.9649 - lr: 5.0000e-04
# Epoch 15/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9563
# Epoch 15: val_loss improved from 0.15045 to 0.14005, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 49s 450ms/step - loss: 0.1445 - accuracy: 0.9563 - val_loss: 0.1401 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 16/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9571
# Epoch 16: val_loss did not improve from 0.14005
# 108/108 [==============================] - 49s 452ms/step - loss: 0.1426 - accuracy: 0.9571 - val_loss: 0.1407 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 17/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9606
# Epoch 17: val_loss improved from 0.14005 to 0.13527, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 50s 460ms/step - loss: 0.1272 - accuracy: 0.9606 - val_loss: 0.1353 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 18/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9600
# Epoch 18: val_loss did not improve from 0.13527
# 108/108 [==============================] - 47s 438ms/step - loss: 0.1300 - accuracy: 0.9600 - val_loss: 0.1465 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 19/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9530
# Epoch 19: val_loss did not improve from 0.13527
# 108/108 [==============================] - 56s 519ms/step - loss: 0.1357 - accuracy: 0.9530 - val_loss: 0.1357 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 20/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9621
# Epoch 20: val_loss improved from 0.13527 to 0.13480, saving model to ../models\best_model2.h5
# 108/108 [==============================] - 55s 506ms/step - loss: 0.1323 - accuracy: 0.9621 - val_loss: 0.1348 - val_accuracy: 0.9605 - lr: 5.0000e-04
# Epoch 21/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1251 - accuracy: 0.9600
# Epoch 21: val_loss did not improve from 0.13480
# 108/108 [==============================] - 87s 808ms/step - loss: 0.1251 - accuracy: 0.9600 - val_loss: 0.1372 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 22/30
# 107/108 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9594
# Epoch 22: val_loss did not improve from 0.13480
# 108/108 [==============================] - 51s 470ms/step - loss: 0.1270 - accuracy: 0.9595 - val_loss: 0.1399 - val_accuracy: 0.9605 - lr: 5.0000e-04
# Epoch 23/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1195 - accuracy: 0.9609
# Epoch 23: val_loss did not improve from 0.13480
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 108/108 [==============================] - 50s 469ms/step - loss: 0.1195 - accuracy: 0.9609 - val_loss: 0.1367 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 24/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9668
# Epoch 24: val_loss did not improve from 0.13480
# 108/108 [==============================] - 50s 464ms/step - loss: 0.1135 - accuracy: 0.9668 - val_loss: 0.1368 - val_accuracy: 0.9649 - lr: 2.5000e-04
# Epoch 25/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9621
# Epoch 25: val_loss did not improve from 0.13480
# 108/108 [==============================] - 50s 461ms/step - loss: 0.1155 - accuracy: 0.9621 - val_loss: 0.1381 - val_accuracy: 0.9605 - lr: 2.5000e-04
# Epoch 26/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9679
# Epoch 26: val_loss did not improve from 0.13480
# Restoring model weights from the end of the best epoch: 20.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 108/108 [==============================] - 47s 436ms/step - loss: 0.1095 - accuracy: 0.9679 - val_loss: 0.1360 - val_accuracy: 0.9605 - lr: 2.5000e-04
# Epoch 26: early stopping

# %%
# ==========================================
# STEP 8: Save final model & metadata
# ==========================================

# --- GABUNGKAN HISTORY (fase 1 + fase 2) ---
# agar grafik & statistik mencakup seluruh pelatihan
combined_history = history.history

# --- Hitung rata-rata akurasi dari fase akhir (fine-tuning) ---
train_acc_avg = np.mean(history.history.get('accuracy', [-1]))
val_acc_avg   = np.mean(history.history.get('val_accuracy', [-1]))

train_acc_int = int(train_acc_avg * 100)
val_acc_int = int(val_acc_avg * 100)

# create versioned folder like before
pattern = re.compile(r"model-rdc-(\d+).(\d+)")
existing_dirs = [d for d in os.listdir(MODEL_DIR) if os.path.isdir(os.path.join(MODEL_DIR, d))]
model_id = MODEL_ID
versions = []
for d in existing_dirs:
    m = pattern.match(d)
    if m and int(m.group(1)) == model_id:
        versions.append(int(m.group(2)))
next_version = max(versions) + 1 if versions else 1

# --- Buat folder penyimpanan baru ---
model_fname = f"model-rdc-{model_id}.{next_version}"
save_dir = os.path.join(MODEL_DIR, model_fname)
os.makedirs(save_dir, exist_ok=True)

# --- Simpan model final (setelah fine-tuning) ---
final_model_path = os.path.join(save_dir, f"model.h5")
model.save(final_model_path)

# --- Simpan label kelas ---
labels = {v: k for k, v in train_generator.class_indices.items()}
with open(os.path.join(save_dir, "labels.json"), "w") as f:
    json.dump(labels, f, indent=4)

# --- Simpan ringkasan metadata model ---
summary = {
    "model_id": model_id,
    "version": next_version,
    "model_name": model_fname,
    "model_use": MODEL_NAME,
    "train_acc_avg": round(float(train_acc_avg) * 100, 2),
    "val_acc_avg": round(float(val_acc_avg) * 100, 2),
    "epochs_phase1": len(history.history.get('accuracy', [])),
    "model_path": final_model_path
}
with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

def to_serializable(obj):
    """Konversi semua numpy type ke tipe Python biasa agar bisa di-dump ke JSON"""
    if isinstance(obj, (np.float32, np.float64)):
        return float(obj)
    if isinstance(obj, (np.int32, np.int64)):
        return int(obj)
    if isinstance(obj, (np.ndarray, list)):
        return [to_serializable(x) for x in obj]
    if isinstance(obj, dict):
        return {k: to_serializable(v) for k, v in obj.items()}
    return obj


# --- Simpan riwayat pelatihan (fase 1, fase 2, dan gabungan) ---
with open(os.path.join(save_dir, "history_phase1.json"), "w") as f:
    json.dump(to_serializable(history.history), f, indent=4)

with open(os.path.join(save_dir, "history_combined.json"), "w") as f:
    json.dump(to_serializable(combined_history), f, indent=4)


print(f"📁 Semua file metadata dan history disimpan di: {save_dir}")
# Out:
# 📁 Semua file metadata dan history disimpan di: ../models\model-rdc-2.1

# %%
# ==========================================
# STEP 9: Plot & save metrics (FINAL)
# ==========================================

# Gunakan combined_history dari STEP 8
acc      = combined_history.get('accuracy', [])
val_acc  = combined_history.get('val_accuracy', [])
loss     = combined_history.get('loss', [])
val_loss = combined_history.get('val_loss', [])

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

# --- Plot Accuracy ---
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Accuracy')
plt.plot(epochs_range, val_acc, label='Val Accuracy')
plt.title("Training & Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# --- Plot Loss ---
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()

# --- Simpan grafik ---
metrics_path = os.path.join(save_dir, "metrics.png")
plt.savefig(metrics_path)
plt.show()
plt.close()

print(f"📈 Grafik akurasi & loss disimpan di: {metrics_path}")
# Out:
# 📈 Grafik akurasi & loss disimpan di: ../models\model-rdc-2.1\metrics.png

# %%
# ==========================================
# STEP 10: Evaluation (validation set)
# ==========================================
print("\n🚀 Evaluasi Model pada Validation Set...")

# --- Reset generator agar prediksi berurutan ---
val_generator.reset()

# --- Prediksi ---
y_pred = model.predict(val_generator, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

# --- Label kelas ---
class_labels = list(val_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Validation):")
report_val = classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_val_path = os.path.join(save_dir, "evaluation_val.json")
with open(eval_val_path, "w") as f:
    json.dump(report_val, f, indent=4)
print(f"✅ Laporan evaluasi validasi disimpan: {eval_val_path}")

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')

# --- Simpan confusion matrix ---
cm_val_path = os.path.join(save_dir, "confusion_matrix_val.png")
plt.tight_layout()
plt.savefig(cm_val_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix validasi disimpan di: {cm_val_path}")
# Out:
# 🚀 Evaluasi Model pada Validation Set...
#
# 📊 Classification Report (Validation):
#               precision    recall  f1-score   support
#
#         alur       1.00      0.80      0.89         5
#       lubang       0.95      0.98      0.97       116
#        retak       0.97      0.96      0.96        93
#  tidak_rusak       1.00      0.86      0.92        14
#
#     accuracy                           0.96       228
#    macro avg       0.98      0.90      0.94       228
# weighted avg       0.96      0.96      0.96       228
#
# ✅ Laporan evaluasi validasi disimpan: ../models\model-rdc-2.1\evaluation_val.json
# 🧩 Confusion matrix validasi disimpan di: ../models\model-rdc-2.1\confusion_matrix_val.png

# %%
# ==========================================
# STEP 11: Testing (test set)
# ==========================================
print("\n🚀 Evaluasi Model pada Test Set...")

# --- Reset generator ---
test_generator.reset()

# --- Evaluasi langsung ---
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"\n📈 Test Accuracy: {test_acc*100:.2f}%  |  Test Loss: {test_loss:.4f}")

# --- Prediksi ---
y_pred_test = model.predict(test_generator, verbose=0)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_true_test = test_generator.classes

# --- Label kelas ---
class_labels = list(test_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Test):")
report_test = classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_test_path = os.path.join(save_dir, "evaluation_test.json")
with open(eval_test_path, "w") as f:
    json.dump(report_test, f, indent=4)
print(f"✅ Laporan evaluasi testing disimpan: {eval_test_path}")

# --- Confusion Matrix ---
cm_test = confusion_matrix(y_true_test, y_pred_test_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Greens',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Test Set')

# --- Simpan confusion matrix ---
cm_test_path = os.path.join(save_dir, "confusion_matrix_test.png")
plt.tight_layout()
plt.savefig(cm_test_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix testing disimpan di: {cm_test_path}")

# --- Simpan ringkasan hasil test ke summary.json ---
summary["test_accuracy"] = round(float(test_acc) * 100, 2)
summary["test_loss"] = round(float(test_loss), 4)

with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

print(f"📘 Summary diperbarui dengan hasil test: {os.path.join(save_dir, 'summary.json')}")
# Out:
# 🚀 Evaluasi Model pada Test Set...
#
# 📈 Test Accuracy: 94.50%  |  Test Loss: 0.1351
#
# 📊 Classification Report (Test):
#               precision    recall  f1-score   support
#
#         alur       0.75      1.00      0.86         6
#       lubang       0.95      0.97      0.96       112
#        retak       0.95      0.93      0.94        90
#  tidak_rusak       1.00      0.70      0.82        10
#
#     accuracy                           0.94       218
#    macro avg       0.91      0.90      0.90       218
# weighted avg       0.95      0.94      0.94       218
#
# ✅ Laporan evaluasi testing disimpan: ../models\model-rdc-2.1\evaluation_test.json
# 🧩 Confusion matrix testing disimpan di: ../models\model-rdc-2.1\confusion_matrix_test.png
# 📘 Summary diperbarui dengan hasil test: ../models\model-rdc-2.1\summary.json
