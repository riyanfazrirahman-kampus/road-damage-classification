# %%
import os
import re
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from collections import Counter

from sklearn.metrics import classification_report, confusion_matrix

# %%
# ==========================================
# STEP 0: PARAMETERS & PATHS (sesuaikan)
# ==========================================
PROCESSED_DIR = "../dataset_split_aug"  # output: train/ val/ test/ per kelas
MODEL_DIR = "../models"
MODEL_ID = 3

IMG_SIZE = (224, 224)   # tuple: target_size untuk flow_from_directory
IMG_SIDE = IMG_SIZE[0]  # integer untuk fungsi make_square
BATCH_SIZE = 32

# Training
TRAIN_EPOCHS = 30
TRAIN_LEARNING_RATE = 0.005

# Fine-Tuning
TUNING_EPOCHS = 20
TUNING_LEARNING_RATE = 1e-5

os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# ==========================================
# TABEL HORIZONTAL
# ==========================================
params = {
    "MODEL": MODEL_ID,
    "LEARNING_RATE": TRAIN_LEARNING_RATE,
    "BATCH": BATCH_SIZE,
    "EPOCHS": TRAIN_EPOCHS,
    "AUGMENTASI": True
}

pd.DataFrame([params])
# Out:
#    MODEL  LEARNING_RATE  BATCH  EPOCHS  AUGMENTASI
# 0      3          0.005     32      30        True

# %%
# ==========================================
# STEP 4: Data generators
# ==========================================

# Train
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
)

# Val
val_datagen = ImageDataGenerator(
    rescale=1./255
)

val_generator = val_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "val"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Test
test_datagen = ImageDataGenerator(
    rescale=1./255
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "test"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1900 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.
# Found 234 images belonging to 4 classes.

# %%
# ==========================================
# (Optional) print counts per class for sanity check
# ==========================================

# hitung jumlah file per class
train_counts = Counter([os.path.split(f)[0] for f in train_generator.filenames])
val_counts   = Counter([os.path.split(f)[0] for f in val_generator.filenames])
test_counts  = Counter([os.path.split(f)[0] for f in test_generator.filenames])

# urutan class mengikuti generator
classes = list(train_generator.class_indices.keys())

# buat tabel
df_counts = pd.DataFrame({
    "class": classes,
    "train": [train_counts.get(cls, 0) for cls in classes],
    "val":   [val_counts.get(cls, 0) for cls in classes],
    "test":  [test_counts.get(cls, 0) for cls in classes]
})

# tambahkan baris total
total_row = pd.DataFrame([{
    "class": "TOTAL",
    "train": df_counts["train"].sum(),
    "val": df_counts["val"].sum(),
    "test": df_counts["test"].sum()
}])

df_counts = pd.concat([df_counts, total_row], ignore_index=True)

df_counts
# Out:
#          class  train  val  test
# 0         alur    485   55    61
# 1       lubang    474   53    58
# 2        retak    465   56    56
# 3  tidak_rusak    476   60    59
# 4        TOTAL   1900  224   234

# %%
# ==========================================
# STEP 5: Build model (MobileNetV2 transfer learning)
# ==========================================

num_classes = train_generator.num_classes

MODEL_NAME = "MobileNetV2"
base_model = MobileNetV2(
    weights='imagenet', 
    include_top=False, 
    input_shape=(IMG_SIDE, IMG_SIDE, 3)
    )

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
preds = Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=preds)

# freeze base
for layer in base_model.layers:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=TRAIN_LEARNING_RATE), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

print("\nModel siap. Jumlah kelas:", num_classes)
# Out:
# Model siap. Jumlah kelas: 4

# %%
# ==========================================
# STEP 6: Callbacks 
# ==========================================

checkpoint_path = os.path.join(MODEL_DIR, "best_model3.h5")
callbacks = [
    ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_loss', verbose=1),
    EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
]

# %%
# ==========================================
# STEP 7: Training
# ==========================================

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=TRAIN_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 0.8987 - accuracy: 0.6616
# Epoch 1: val_loss improved from inf to 0.44022, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 84s 1s/step - loss: 0.8987 - accuracy: 0.6616 - val_loss: 0.4402 - val_accuracy: 0.8259 - lr: 0.0050
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 0.5629 - accuracy: 0.7963
# Epoch 2: val_loss improved from 0.44022 to 0.26744, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 49s 817ms/step - loss: 0.5629 - accuracy: 0.7963 - val_loss: 0.2674 - val_accuracy: 0.9152 - lr: 0.0050
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.5002 - accuracy: 0.7979
# Epoch 3: val_loss did not improve from 0.26744
# 60/60 [==============================] - 51s 849ms/step - loss: 0.5002 - accuracy: 0.7979 - val_loss: 0.3155 - val_accuracy: 0.8973 - lr: 0.0050
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.8221
# Epoch 4: val_loss did not improve from 0.26744
# 60/60 [==============================] - 48s 797ms/step - loss: 0.4605 - accuracy: 0.8221 - val_loss: 0.3045 - val_accuracy: 0.8884 - lr: 0.0050
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.4820 - accuracy: 0.8379
# Epoch 5: val_loss did not improve from 0.26744
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 60/60 [==============================] - 48s 796ms/step - loss: 0.4820 - accuracy: 0.8379 - val_loss: 0.2790 - val_accuracy: 0.9062 - lr: 0.0050
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.4353 - accuracy: 0.8416
# Epoch 6: val_loss improved from 0.26744 to 0.24235, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 47s 786ms/step - loss: 0.4353 - accuracy: 0.8416 - val_loss: 0.2423 - val_accuracy: 0.9196 - lr: 0.0025
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3956 - accuracy: 0.8558
# Epoch 7: val_loss did not improve from 0.24235
# 60/60 [==============================] - 47s 781ms/step - loss: 0.3956 - accuracy: 0.8558 - val_loss: 0.2530 - val_accuracy: 0.8929 - lr: 0.0025
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8611
# Epoch 8: val_loss improved from 0.24235 to 0.24138, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 46s 760ms/step - loss: 0.3965 - accuracy: 0.8611 - val_loss: 0.2414 - val_accuracy: 0.9152 - lr: 0.0025
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3889 - accuracy: 0.8511
# Epoch 9: val_loss did not improve from 0.24138
# 60/60 [==============================] - 46s 766ms/step - loss: 0.3889 - accuracy: 0.8511 - val_loss: 0.3093 - val_accuracy: 0.8839 - lr: 0.0025
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.4134 - accuracy: 0.8463
# Epoch 10: val_loss did not improve from 0.24138
# 60/60 [==============================] - 46s 764ms/step - loss: 0.4134 - accuracy: 0.8463 - val_loss: 0.2568 - val_accuracy: 0.8929 - lr: 0.0025
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3564 - accuracy: 0.8711
# Epoch 11: val_loss improved from 0.24138 to 0.21588, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 46s 765ms/step - loss: 0.3564 - accuracy: 0.8711 - val_loss: 0.2159 - val_accuracy: 0.9330 - lr: 0.0025
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.4070 - accuracy: 0.8500
# Epoch 12: val_loss did not improve from 0.21588
# 60/60 [==============================] - 46s 767ms/step - loss: 0.4070 - accuracy: 0.8500 - val_loss: 0.2294 - val_accuracy: 0.9241 - lr: 0.0025
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3828 - accuracy: 0.8642
# Epoch 13: val_loss did not improve from 0.21588
# 60/60 [==============================] - 46s 772ms/step - loss: 0.3828 - accuracy: 0.8642 - val_loss: 0.2350 - val_accuracy: 0.8929 - lr: 0.0025
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.8674
# Epoch 14: val_loss did not improve from 0.21588
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 60/60 [==============================] - 49s 814ms/step - loss: 0.3728 - accuracy: 0.8674 - val_loss: 0.3586 - val_accuracy: 0.8348 - lr: 0.0025
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8842
# Epoch 15: val_loss improved from 0.21588 to 0.19604, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 47s 779ms/step - loss: 0.3316 - accuracy: 0.8842 - val_loss: 0.1960 - val_accuracy: 0.9375 - lr: 0.0012
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3271 - accuracy: 0.8911
# Epoch 16: val_loss did not improve from 0.19604
# 60/60 [==============================] - 46s 760ms/step - loss: 0.3271 - accuracy: 0.8911 - val_loss: 0.2837 - val_accuracy: 0.8661 - lr: 0.0012
# Epoch 17/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.8621
# Epoch 17: val_loss did not improve from 0.19604
# 60/60 [==============================] - 45s 756ms/step - loss: 0.3622 - accuracy: 0.8621 - val_loss: 0.2207 - val_accuracy: 0.9152 - lr: 0.0012
# Epoch 18/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3215 - accuracy: 0.8789
# Epoch 18: val_loss did not improve from 0.19604
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 60/60 [==============================] - 45s 750ms/step - loss: 0.3215 - accuracy: 0.8789 - val_loss: 0.2024 - val_accuracy: 0.9286 - lr: 0.0012
# Epoch 19/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3320 - accuracy: 0.8774
# Epoch 19: val_loss did not improve from 0.19604
# 60/60 [==============================] - 44s 729ms/step - loss: 0.3320 - accuracy: 0.8774 - val_loss: 0.2132 - val_accuracy: 0.9286 - lr: 6.2500e-04
# Epoch 20/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3219 - accuracy: 0.8795
# Epoch 20: val_loss did not improve from 0.19604
# 60/60 [==============================] - 44s 729ms/step - loss: 0.3219 - accuracy: 0.8795 - val_loss: 0.1990 - val_accuracy: 0.9330 - lr: 6.2500e-04
# Epoch 21/30
# 60/60 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.8811
# Epoch 21: val_loss did not improve from 0.19604
# Restoring model weights from the end of the best epoch: 15.
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 60/60 [==============================] - 44s 731ms/step - loss: 0.3149 - accuracy: 0.8811 - val_loss: 0.1973 - val_accuracy: 0.9375 - lr: 6.2500e-04
# Epoch 21: early stopping

# %%
# ==========================================
# STEP 8: Fine-tuning (fase kedua)
# ==========================================

# Unfreeze 50 layer terakhir dari base model
for layer in base_model.layers[-50:]:
    layer.trainable = True

# Compile ulang dengan learning rate lebih kecil
model.compile(
    optimizer=Adam(learning_rate=TUNING_LEARNING_RATE),  # LR kecil untuk fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Latih ulang model (fine-tuning)
history_finetune = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=TUNING_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 60/60 [==============================] - ETA: 0s - loss: 0.9474 - accuracy: 0.6995
# Epoch 1: val_loss improved from 0.19604 to 0.18639, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 51s 768ms/step - loss: 0.9474 - accuracy: 0.6995 - val_loss: 0.1864 - val_accuracy: 0.9330 - lr: 1.0000e-05
# Epoch 2/20
# 60/60 [==============================] - ETA: 0s - loss: 0.7331 - accuracy: 0.7479
# Epoch 2: val_loss improved from 0.18639 to 0.17960, saving model to ../models\best_model3.h5
# 60/60 [==============================] - 47s 785ms/step - loss: 0.7331 - accuracy: 0.7479 - val_loss: 0.1796 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 3/20
# 60/60 [==============================] - ETA: 0s - loss: 0.6349 - accuracy: 0.7842
# Epoch 3: val_loss did not improve from 0.17960
# 60/60 [==============================] - 45s 748ms/step - loss: 0.6349 - accuracy: 0.7842 - val_loss: 0.1928 - val_accuracy: 0.9286 - lr: 1.0000e-05
# Epoch 4/20
# 60/60 [==============================] - ETA: 0s - loss: 0.5388 - accuracy: 0.8011
# Epoch 4: val_loss did not improve from 0.17960
# 60/60 [==============================] - 45s 744ms/step - loss: 0.5388 - accuracy: 0.8011 - val_loss: 0.1877 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 5/20
# 60/60 [==============================] - ETA: 0s - loss: 0.5029 - accuracy: 0.8132
# Epoch 5: val_loss did not improve from 0.17960
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 60/60 [==============================] - 44s 738ms/step - loss: 0.5029 - accuracy: 0.8132 - val_loss: 0.1893 - val_accuracy: 0.9330 - lr: 1.0000e-05
# Epoch 6/20
# 60/60 [==============================] - ETA: 0s - loss: 0.4942 - accuracy: 0.8232
# Epoch 6: val_loss did not improve from 0.17960
# 60/60 [==============================] - 45s 740ms/step - loss: 0.4942 - accuracy: 0.8232 - val_loss: 0.2026 - val_accuracy: 0.9241 - lr: 5.0000e-06
# Epoch 7/20
# 60/60 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8263
# Epoch 7: val_loss did not improve from 0.17960
# 60/60 [==============================] - 46s 762ms/step - loss: 0.4803 - accuracy: 0.8263 - val_loss: 0.2172 - val_accuracy: 0.9286 - lr: 5.0000e-06
# Epoch 8/20
# 60/60 [==============================] - ETA: 0s - loss: 0.4752 - accuracy: 0.8395
# Epoch 8: val_loss did not improve from 0.17960
# Restoring model weights from the end of the best epoch: 2.
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 60/60 [==============================] - 45s 745ms/step - loss: 0.4752 - accuracy: 0.8395 - val_loss: 0.2039 - val_accuracy: 0.9286 - lr: 5.0000e-06
# Epoch 8: early stopping

# %%
# ==========================================
# STEP 8: Save final model & metadata
# ==========================================

# --- GABUNGKAN HISTORY (fase 1 + fase 2) ---
# agar grafik & statistik mencakup seluruh pelatihan
combined_history = {}
for key in history.history.keys():
    combined_history[key] = history.history[key] + history_finetune.history.get(key, [])

# --- Hitung rata-rata akurasi dari fase akhir (fine-tuning) ---
train_acc_avg = np.mean(history_finetune.history.get('accuracy', history.history.get('accuracy', [-1])))
val_acc_avg   = np.mean(history_finetune.history.get('val_accuracy', history.history.get('val_accuracy', [-1])))

train_acc_int = int(train_acc_avg * 100)
val_acc_int = int(val_acc_avg * 100)

# create versioned folder like before
pattern = re.compile(r"Model-RDC-(\d+).(\d+)")
existing_dirs = [d for d in os.listdir(MODEL_DIR) if os.path.isdir(os.path.join(MODEL_DIR, d))]
model_id = MODEL_ID
versions = []
for d in existing_dirs:
    m = pattern.match(d)
    if m and int(m.group(1)) == model_id:
        versions.append(int(m.group(2)))
next_version = max(versions) + 1 if versions else 1

# --- Buat folder penyimpanan baru ---
model_fname = f"Model-RDC-{model_id}.{next_version}"
save_dir = os.path.join(MODEL_DIR, model_fname)
os.makedirs(save_dir, exist_ok=True)

# --- Simpan model final (setelah fine-tuning) ---
final_model_path = os.path.join(save_dir, f"model.h5")
model.save(final_model_path)

# --- Simpan label kelas ---
labels = {v: k for k, v in train_generator.class_indices.items()}
with open(os.path.join(save_dir, "labels.json"), "w") as f:
    json.dump(labels, f, indent=4)

# --- Simpan ringkasan metadata model ---
summary = {
    "model_id": model_id,
    "version": next_version,
    "model_name": model_fname,
    "model_use": MODEL_NAME,
    "train_acc_avg": round(float(train_acc_avg) * 100, 2),
    "val_acc_avg": round(float(val_acc_avg) * 100, 2),
    "epochs_phase1": len(history.history.get('accuracy', [])),
    "epochs_phase2": len(history_finetune.history.get('accuracy', [])),
    "model_path": final_model_path
}
with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

def to_serializable(obj):
    """Konversi semua numpy type ke tipe Python biasa agar bisa di-dump ke JSON"""
    if isinstance(obj, (np.float32, np.float64)):
        return float(obj)
    if isinstance(obj, (np.int32, np.int64)):
        return int(obj)
    if isinstance(obj, (np.ndarray, list)):
        return [to_serializable(x) for x in obj]
    if isinstance(obj, dict):
        return {k: to_serializable(v) for k, v in obj.items()}
    return obj


# --- Simpan riwayat pelatihan (fase 1, fase 2, dan gabungan) ---
with open(os.path.join(save_dir, "history_phase1.json"), "w") as f:
    json.dump(to_serializable(history.history), f, indent=4)

with open(os.path.join(save_dir, "history_finetune.json"), "w") as f:
    json.dump(to_serializable(history_finetune.history), f, indent=4)

with open(os.path.join(save_dir, "history_combined.json"), "w") as f:
    json.dump(to_serializable(combined_history), f, indent=4)


print(f"📁 Semua file metadata dan history disimpan di: {save_dir}")
# Out:
# 📁 Semua file metadata dan history disimpan di: ../models\Model-RDC-3.2

# %%
# ==========================================
# STEP 9: Plot & save metrics (FINAL)
# ==========================================

# Gunakan combined_history dari STEP 8
acc      = combined_history.get('accuracy', [])
val_acc  = combined_history.get('val_accuracy', [])
loss     = combined_history.get('loss', [])
val_loss = combined_history.get('val_loss', [])

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

# --- Plot Accuracy ---
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Accuracy')
plt.plot(epochs_range, val_acc, label='Val Accuracy')
plt.title("Training & Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# --- Plot Loss ---
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()

# --- Simpan grafik ---
metrics_path = os.path.join(save_dir, "metrics.png")
plt.savefig(metrics_path)
plt.show()
plt.close()

print(f"📈 Grafik akurasi & loss disimpan di: {metrics_path}")
# Out:
# 📈 Grafik akurasi & loss disimpan di: ../models\Model-RDC-3.2\metrics.png

# %%
# ==========================================
# STEP 10: Evaluation (validation set)
# ==========================================
print("\n🚀 Evaluasi Model pada Validation Set...")

# --- Reset generator agar prediksi berurutan ---
val_generator.reset()

# --- Prediksi ---
y_pred = model.predict(val_generator, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

# --- Label kelas ---
class_labels = list(val_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Validation):")
report_val = classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_val_path = os.path.join(save_dir, "evaluation_val.json")
with open(eval_val_path, "w") as f:
    json.dump(report_val, f, indent=4)
print(f"✅ Laporan evaluasi validasi disimpan: {eval_val_path}")

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')

# --- Simpan confusion matrix ---
cm_val_path = os.path.join(save_dir, "confusion_matrix_val.png")
plt.tight_layout()
plt.savefig(cm_val_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix validasi disimpan di: {cm_val_path}")
# Out:
# 🚀 Evaluasi Model pada Validation Set...
#
# 📊 Classification Report (Validation):
#               precision    recall  f1-score   support
#
#         alur       0.93      0.96      0.95        55
#       lubang       1.00      0.92      0.96        53
#        retak       0.88      0.95      0.91        56
#  tidak_rusak       0.95      0.92      0.93        60
#
#     accuracy                           0.94       224
#    macro avg       0.94      0.94      0.94       224
# weighted avg       0.94      0.94      0.94       224
#
# ✅ Laporan evaluasi validasi disimpan: ../models\Model-RDC-3.2\evaluation_val.json
# 🧩 Confusion matrix validasi disimpan di: ../models\Model-RDC-3.2\confusion_matrix_val.png

# %%
# ==========================================
# STEP 11: Testing (test set)
# ==========================================
print("\n🚀 Evaluasi Model pada Test Set...")

# --- Reset generator ---
test_generator.reset()

# --- Evaluasi langsung ---
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"\n📈 Test Accuracy: {test_acc*100:.2f}%  |  Test Loss: {test_loss:.4f}")

# --- Prediksi ---
y_pred_test = model.predict(test_generator, verbose=0)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_true_test = test_generator.classes

# --- Label kelas ---
class_labels = list(test_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Test):")
report_test = classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_test_path = os.path.join(save_dir, "evaluation_test.json")
with open(eval_test_path, "w") as f:
    json.dump(report_test, f, indent=4)
print(f"✅ Laporan evaluasi testing disimpan: {eval_test_path}")

# --- Confusion Matrix ---
cm_test = confusion_matrix(y_true_test, y_pred_test_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Test Set')

# --- Simpan confusion matrix ---
cm_test_path = os.path.join(save_dir, "confusion_matrix_test.png")
plt.tight_layout()
plt.savefig(cm_test_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix testing disimpan di: {cm_test_path}")

# --- Simpan ringkasan hasil test ke summary.json ---
summary["test_accuracy"] = round(float(test_acc) * 100, 2)
summary["test_loss"] = round(float(test_loss), 4)

with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

print(f"📘 Summary diperbarui dengan hasil test: {os.path.join(save_dir, 'summary.json')}")
# Out:
# 🚀 Evaluasi Model pada Test Set...
#
# 📈 Test Accuracy: 93.59%  |  Test Loss: 0.1850
#
# 📊 Classification Report (Test):
#               precision    recall  f1-score   support
#
#         alur       0.87      0.95      0.91        61
#       lubang       0.95      0.91      0.93        58
#        retak       0.96      0.89      0.93        56
#  tidak_rusak       0.98      0.98      0.98        59
#
#     accuracy                           0.94       234
#    macro avg       0.94      0.94      0.94       234
# weighted avg       0.94      0.94      0.94       234
#
# ✅ Laporan evaluasi testing disimpan: ../models\Model-RDC-3.2\evaluation_test.json
# 🧩 Confusion matrix testing disimpan di: ../models\Model-RDC-3.2\confusion_matrix_test.png
# 📘 Summary diperbarui dengan hasil test: ../models\Model-RDC-3.2\summary.json
