# %%
import os
import re
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from collections import Counter

from sklearn.metrics import classification_report, confusion_matrix

# %%
# ==========================================
# STEP 0: PARAMETERS & PATHS (sesuaikan)
# ==========================================
PROCESSED_DIR = "../dataset_processed_aug"  # output: train/ val/ test/ per kelas
MODEL_DIR = "../models"
MODEL_ID = 3

IMG_SIZE = (224, 224)   # tuple: target_size untuk flow_from_directory
IMG_SIDE = IMG_SIZE[0]  # integer untuk fungsi make_square
BATCH_SIZE = 32

# Training
TRAIN_EPOCHS = 30
TRAIN_DROPOUT = 0.3
TRAIN_LEARNING_RATE = 0.0005

# Fine-Tuning
TUNING_EPOCHS = 20
TUNING_LEARNING_RATE = 1e-5

os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# ==========================================
# TABEL HORIZONTAL
# ==========================================
params = {
    "MODEL": MODEL_ID,
    "LEARNING_RATE": TRAIN_LEARNING_RATE,
    "BATCH": BATCH_SIZE,
    "EPOCHS": TRAIN_EPOCHS,
    "DROPOUT": TRAIN_DROPOUT,
    "AUGMENTASI": True
}

pd.DataFrame([params])
# Out:
#    MODEL  LEARNING_RATE  BATCH  EPOCHS  DROPOUT  AUGMENTASI
# 0      3         0.0005     32      30        0        True

# %%
# ==========================================
# STEP 4: Data generators
# - train: augmentation + rescale
# - val/test: hanya rescale
# ==========================================

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)

valtest_datagen = ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
)

val_generator = valtest_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "val"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = valtest_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "test"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 3429 images belonging to 4 classes.
# Found 228 images belonging to 4 classes.
# Found 218 images belonging to 4 classes.

# %%
print("Generators siap:")
print(" - train samples:", train_generator.samples)
print(" - val samples:", val_generator.samples)
print(" - test samples:", test_generator.samples)
print("Classes:", train_generator.class_indices)

X_batch, Y_batch = next(train_generator)

print(X_batch.shape)  
print(Y_batch.shape)  # contoh: (32, jumlah_kelas)
print(Y_batch[0])     # label one-hot gambar pertama
# Out:
# Generators siap:
#  - train samples: 3429
#  - val samples: 228
#  - test samples: 218
# Classes: {'alur': 0, 'lubang': 1, 'retak': 2, 'tidak_rusak': 3}
# (32, 224, 224, 3)
# (32, 4)
# [0. 0. 1. 0.]

# %%
# ==========================================
# (Optional) print counts per class for sanity check
# ==========================================

print("\nCounts per class (train):")
train_counts = Counter([os.path.split(f)[0] for f in train_generator.filenames])
for cls, idx in train_generator.class_indices.items():
    print(f" - {cls}: {train_counts[cls]}")

print("\nCounts per class (val):")
val_counts = Counter([os.path.split(f)[0] for f in val_generator.filenames])
for cls, idx in val_generator.class_indices.items():
    print(f" - {cls}: {val_counts[cls]}")

print("\nCounts per class (test):")
val_counts = Counter([os.path.split(f)[0] for f in test_generator.filenames])
for cls, idx in val_generator.class_indices.items():
    print(f" - {cls}: {val_counts[cls]}")
# Out:
# Counts per class (train):
#  - alur: 857
#  - lubang: 858
#  - retak: 857
#  - tidak_rusak: 857
#
# Counts per class (val):
#  - alur: 5
#  - lubang: 116
#  - retak: 93
#  - tidak_rusak: 14
#
# Counts per class (test):
#  - alur: 6
#  - lubang: 112
#  - retak: 90
#  - tidak_rusak: 10

# %%
# ==========================================
# STEP 5: Build model (MobileNetV2 transfer learning)
# ==========================================

num_classes = train_generator.num_classes

MODEL_NAME = "MobileNetV2"
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIDE, IMG_SIDE, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(TRAIN_DROPOUT)(x)
preds = Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=preds)

# freeze base
for layer in base_model.layers:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=TRAIN_LEARNING_RATE), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

print("\nModel siap. Jumlah kelas:", num_classes)
# Out:
# Model siap. Jumlah kelas: 4

# %%
# ==========================================
# STEP 6: Callbacks 
# ==========================================

checkpoint_path = os.path.join(MODEL_DIR, "best_model3.h5")
callbacks = [
    ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_loss', verbose=1),
    EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
]

# %%
# ==========================================
# STEP 7: Training
# ==========================================

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=TRAIN_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 108/108 [==============================] - ETA: 0s - loss: 0.8675 - accuracy: 0.6643
# Epoch 1: val_loss improved from inf to 0.51007, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 41s 377ms/step - loss: 0.8675 - accuracy: 0.6643 - val_loss: 0.5101 - val_accuracy: 0.8289 - lr: 5.0000e-04
# Epoch 2/30
# 108/108 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.8376
# Epoch 2: val_loss improved from 0.51007 to 0.35880, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 37s 343ms/step - loss: 0.4873 - accuracy: 0.8376 - val_loss: 0.3588 - val_accuracy: 0.8904 - lr: 5.0000e-04
# Epoch 3/30
# 108/108 [==============================] - ETA: 0s - loss: 0.3765 - accuracy: 0.8793
# Epoch 3: val_loss improved from 0.35880 to 0.32707, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 36s 331ms/step - loss: 0.3765 - accuracy: 0.8793 - val_loss: 0.3271 - val_accuracy: 0.8904 - lr: 5.0000e-04
# Epoch 4/30
# 108/108 [==============================] - ETA: 0s - loss: 0.3170 - accuracy: 0.9000
# Epoch 4: val_loss improved from 0.32707 to 0.26638, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 36s 332ms/step - loss: 0.3170 - accuracy: 0.9000 - val_loss: 0.2664 - val_accuracy: 0.9254 - lr: 5.0000e-04
# Epoch 5/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.9143
# Epoch 5: val_loss improved from 0.26638 to 0.25275, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 36s 334ms/step - loss: 0.2754 - accuracy: 0.9143 - val_loss: 0.2527 - val_accuracy: 0.9254 - lr: 5.0000e-04
# Epoch 6/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.9175
# Epoch 6: val_loss improved from 0.25275 to 0.23576, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 37s 345ms/step - loss: 0.2626 - accuracy: 0.9175 - val_loss: 0.2358 - val_accuracy: 0.9298 - lr: 5.0000e-04
# Epoch 7/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9268
# Epoch 7: val_loss improved from 0.23576 to 0.22370, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 36s 331ms/step - loss: 0.2343 - accuracy: 0.9268 - val_loss: 0.2237 - val_accuracy: 0.9123 - lr: 5.0000e-04
# Epoch 8/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9245
# Epoch 8: val_loss improved from 0.22370 to 0.21253, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 35s 324ms/step - loss: 0.2304 - accuracy: 0.9245 - val_loss: 0.2125 - val_accuracy: 0.9254 - lr: 5.0000e-04
# Epoch 9/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9373
# Epoch 9: val_loss improved from 0.21253 to 0.20220, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 36s 331ms/step - loss: 0.2093 - accuracy: 0.9373 - val_loss: 0.2022 - val_accuracy: 0.9386 - lr: 5.0000e-04
# Epoch 10/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2078 - accuracy: 0.9335
# Epoch 10: val_loss improved from 0.20220 to 0.19410, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 36s 337ms/step - loss: 0.2078 - accuracy: 0.9335 - val_loss: 0.1941 - val_accuracy: 0.9386 - lr: 5.0000e-04
# Epoch 11/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9390
# Epoch 11: val_loss improved from 0.19410 to 0.19073, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 39s 364ms/step - loss: 0.1963 - accuracy: 0.9390 - val_loss: 0.1907 - val_accuracy: 0.9342 - lr: 5.0000e-04
# Epoch 12/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9446
# Epoch 12: val_loss improved from 0.19073 to 0.18978, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 52s 481ms/step - loss: 0.1846 - accuracy: 0.9446 - val_loss: 0.1898 - val_accuracy: 0.9386 - lr: 5.0000e-04
# Epoch 13/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9469
# Epoch 13: val_loss improved from 0.18978 to 0.17938, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 53s 494ms/step - loss: 0.1733 - accuracy: 0.9469 - val_loss: 0.1794 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 14/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9507
# Epoch 14: val_loss did not improve from 0.17938
# 108/108 [==============================] - 49s 451ms/step - loss: 0.1659 - accuracy: 0.9507 - val_loss: 0.1797 - val_accuracy: 0.9474 - lr: 5.0000e-04
# Epoch 15/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9484
# Epoch 15: val_loss improved from 0.17938 to 0.17240, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 48s 443ms/step - loss: 0.1689 - accuracy: 0.9484 - val_loss: 0.1724 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 16/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9528
# Epoch 16: val_loss did not improve from 0.17240
# 108/108 [==============================] - 47s 433ms/step - loss: 0.1633 - accuracy: 0.9528 - val_loss: 0.1919 - val_accuracy: 0.9254 - lr: 5.0000e-04
# Epoch 17/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1664 - accuracy: 0.9469
# Epoch 17: val_loss improved from 0.17240 to 0.17123, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 47s 432ms/step - loss: 0.1664 - accuracy: 0.9469 - val_loss: 0.1712 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 18/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9557
# Epoch 18: val_loss did not improve from 0.17123
# 108/108 [==============================] - 56s 517ms/step - loss: 0.1523 - accuracy: 0.9557 - val_loss: 0.1752 - val_accuracy: 0.9386 - lr: 5.0000e-04
# Epoch 19/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9548
# Epoch 19: val_loss improved from 0.17123 to 0.16412, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 43s 401ms/step - loss: 0.1434 - accuracy: 0.9548 - val_loss: 0.1641 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 20/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9525
# Epoch 20: val_loss did not improve from 0.16412
# 108/108 [==============================] - 41s 381ms/step - loss: 0.1491 - accuracy: 0.9525 - val_loss: 0.1672 - val_accuracy: 0.9474 - lr: 5.0000e-04
# Epoch 21/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9603
# Epoch 21: val_loss did not improve from 0.16412
# 108/108 [==============================] - 48s 447ms/step - loss: 0.1396 - accuracy: 0.9603 - val_loss: 0.1761 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 22/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9568
# Epoch 22: val_loss improved from 0.16412 to 0.15351, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 65s 607ms/step - loss: 0.1329 - accuracy: 0.9568 - val_loss: 0.1535 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 23/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9565
# Epoch 23: val_loss did not improve from 0.15351
# 108/108 [==============================] - 88s 810ms/step - loss: 0.1377 - accuracy: 0.9565 - val_loss: 0.1645 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 24/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9606
# Epoch 24: val_loss improved from 0.15351 to 0.15109, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 782ms/step - loss: 0.1341 - accuracy: 0.9606 - val_loss: 0.1511 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 25/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9563
# Epoch 25: val_loss did not improve from 0.15109
# 108/108 [==============================] - 84s 775ms/step - loss: 0.1322 - accuracy: 0.9563 - val_loss: 0.1670 - val_accuracy: 0.9474 - lr: 5.0000e-04
# Epoch 26/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9586
# Epoch 26: val_loss did not improve from 0.15109
# 108/108 [==============================] - 89s 820ms/step - loss: 0.1239 - accuracy: 0.9586 - val_loss: 0.1542 - val_accuracy: 0.9474 - lr: 5.0000e-04
# Epoch 27/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9554
# Epoch 27: val_loss improved from 0.15109 to 0.14314, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 790ms/step - loss: 0.1367 - accuracy: 0.9554 - val_loss: 0.1431 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 28/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.9612
# Epoch 28: val_loss did not improve from 0.14314
# 108/108 [==============================] - 85s 790ms/step - loss: 0.1273 - accuracy: 0.9612 - val_loss: 0.1463 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 29/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9609
# Epoch 29: val_loss improved from 0.14314 to 0.14062, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 87s 805ms/step - loss: 0.1265 - accuracy: 0.9609 - val_loss: 0.1406 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 30/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9635
# Epoch 30: val_loss did not improve from 0.14062
# 108/108 [==============================] - 88s 813ms/step - loss: 0.1181 - accuracy: 0.9635 - val_loss: 0.1469 - val_accuracy: 0.9518 - lr: 5.0000e-04

# %%
# ==========================================
# STEP 8: Fine-tuning (fase kedua)
# ==========================================

# Unfreeze 50 layer terakhir dari base model
for layer in base_model.layers[-50:]:
    layer.trainable = True

# Compile ulang dengan learning rate lebih kecil
model.compile(
    optimizer=Adam(learning_rate=TUNING_LEARNING_RATE),  # LR kecil untuk fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Latih ulang model (fine-tuning)
history_finetune = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=TUNING_EPOCHS,
   callbacks=callbacks
)
# Out:
# Epoch 1/30
# 108/108 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.7929
# Epoch 1: val_loss improved from 0.14062 to 0.13819, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 89s 772ms/step - loss: 0.6018 - accuracy: 0.7929 - val_loss: 0.1382 - val_accuracy: 0.9518 - lr: 1.0000e-05
# Epoch 2/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2522 - accuracy: 0.9099
# Epoch 2: val_loss improved from 0.13819 to 0.13487, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 788ms/step - loss: 0.2522 - accuracy: 0.9099 - val_loss: 0.1349 - val_accuracy: 0.9561 - lr: 1.0000e-05
# Epoch 3/30
# 108/108 [==============================] - ETA: 0s - loss: 0.2145 - accuracy: 0.9181
# Epoch 3: val_loss did not improve from 0.13487
# 108/108 [==============================] - 81s 747ms/step - loss: 0.2145 - accuracy: 0.9181 - val_loss: 0.1384 - val_accuracy: 0.9474 - lr: 1.0000e-05
# Epoch 4/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1824 - accuracy: 0.9341
# Epoch 4: val_loss did not improve from 0.13487
# 108/108 [==============================] - 82s 761ms/step - loss: 0.1824 - accuracy: 0.9341 - val_loss: 0.1421 - val_accuracy: 0.9518 - lr: 1.0000e-05
# Epoch 5/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9437
# Epoch 5: val_loss did not improve from 0.13487
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 108/108 [==============================] - 84s 772ms/step - loss: 0.1639 - accuracy: 0.9437 - val_loss: 0.1355 - val_accuracy: 0.9518 - lr: 1.0000e-05
# Epoch 6/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9455
# Epoch 6: val_loss improved from 0.13487 to 0.12843, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 83s 770ms/step - loss: 0.1511 - accuracy: 0.9455 - val_loss: 0.1284 - val_accuracy: 0.9561 - lr: 5.0000e-06
# Epoch 7/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9542
# Epoch 7: val_loss improved from 0.12843 to 0.11755, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 83s 768ms/step - loss: 0.1319 - accuracy: 0.9542 - val_loss: 0.1175 - val_accuracy: 0.9649 - lr: 5.0000e-06
# Epoch 8/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1330 - accuracy: 0.9568
# Epoch 8: val_loss improved from 0.11755 to 0.10420, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 84s 774ms/step - loss: 0.1330 - accuracy: 0.9568 - val_loss: 0.1042 - val_accuracy: 0.9649 - lr: 5.0000e-06
# Epoch 9/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9618
# Epoch 9: val_loss improved from 0.10420 to 0.10290, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 84s 773ms/step - loss: 0.1185 - accuracy: 0.9618 - val_loss: 0.1029 - val_accuracy: 0.9649 - lr: 5.0000e-06
# Epoch 10/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9624
# Epoch 10: val_loss improved from 0.10290 to 0.10048, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 83s 768ms/step - loss: 0.1098 - accuracy: 0.9624 - val_loss: 0.1005 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 11/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9668
# Epoch 11: val_loss improved from 0.10048 to 0.09467, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 86s 799ms/step - loss: 0.0966 - accuracy: 0.9668 - val_loss: 0.0947 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 12/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9659
# Epoch 12: val_loss improved from 0.09467 to 0.09233, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 783ms/step - loss: 0.0976 - accuracy: 0.9659 - val_loss: 0.0923 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 13/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9679
# Epoch 13: val_loss improved from 0.09233 to 0.08887, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 86s 797ms/step - loss: 0.0993 - accuracy: 0.9679 - val_loss: 0.0889 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 14/30
# 108/108 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9697
# Epoch 14: val_loss did not improve from 0.08887
# 108/108 [==============================] - 84s 780ms/step - loss: 0.1008 - accuracy: 0.9697 - val_loss: 0.0930 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 15/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9697
# Epoch 15: val_loss improved from 0.08887 to 0.08767, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 789ms/step - loss: 0.0911 - accuracy: 0.9697 - val_loss: 0.0877 - val_accuracy: 0.9781 - lr: 5.0000e-06
# Epoch 16/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9691
# Epoch 16: val_loss improved from 0.08767 to 0.08091, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 89s 823ms/step - loss: 0.0891 - accuracy: 0.9691 - val_loss: 0.0809 - val_accuracy: 0.9781 - lr: 5.0000e-06
# Epoch 17/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9705
# Epoch 17: val_loss improved from 0.08091 to 0.08074, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 86s 794ms/step - loss: 0.0905 - accuracy: 0.9705 - val_loss: 0.0807 - val_accuracy: 0.9737 - lr: 5.0000e-06
# Epoch 18/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9749
# Epoch 18: val_loss improved from 0.08074 to 0.07937, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 86s 799ms/step - loss: 0.0755 - accuracy: 0.9749 - val_loss: 0.0794 - val_accuracy: 0.9781 - lr: 5.0000e-06
# Epoch 19/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9746
# Epoch 19: val_loss did not improve from 0.07937
# 108/108 [==============================] - 84s 777ms/step - loss: 0.0785 - accuracy: 0.9746 - val_loss: 0.0803 - val_accuracy: 0.9693 - lr: 5.0000e-06
# Epoch 20/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9720
# Epoch 20: val_loss improved from 0.07937 to 0.07913, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 786ms/step - loss: 0.0796 - accuracy: 0.9720 - val_loss: 0.0791 - val_accuracy: 0.9693 - lr: 5.0000e-06
# Epoch 21/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9781
# Epoch 21: val_loss did not improve from 0.07913
# 108/108 [==============================] - 128s 1s/step - loss: 0.0678 - accuracy: 0.9781 - val_loss: 0.0809 - val_accuracy: 0.9693 - lr: 5.0000e-06
# Epoch 22/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0698 - accuracy: 0.9755
# Epoch 22: val_loss improved from 0.07913 to 0.07856, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 99s 918ms/step - loss: 0.0698 - accuracy: 0.9755 - val_loss: 0.0786 - val_accuracy: 0.9737 - lr: 5.0000e-06
# Epoch 23/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9773
# Epoch 23: val_loss improved from 0.07856 to 0.07824, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 785ms/step - loss: 0.0669 - accuracy: 0.9773 - val_loss: 0.0782 - val_accuracy: 0.9693 - lr: 5.0000e-06
# Epoch 24/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9781
# Epoch 24: val_loss improved from 0.07824 to 0.07673, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 782ms/step - loss: 0.0705 - accuracy: 0.9781 - val_loss: 0.0767 - val_accuracy: 0.9781 - lr: 5.0000e-06
# Epoch 25/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9796
# Epoch 25: val_loss did not improve from 0.07673
# 108/108 [==============================] - 84s 772ms/step - loss: 0.0596 - accuracy: 0.9796 - val_loss: 0.0775 - val_accuracy: 0.9781 - lr: 5.0000e-06
# Epoch 26/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9808
# Epoch 26: val_loss did not improve from 0.07673
# 108/108 [==============================] - 86s 791ms/step - loss: 0.0612 - accuracy: 0.9808 - val_loss: 0.0774 - val_accuracy: 0.9693 - lr: 5.0000e-06
# Epoch 27/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9781
# Epoch 27: val_loss did not improve from 0.07673
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 108/108 [==============================] - 83s 766ms/step - loss: 0.0655 - accuracy: 0.9781 - val_loss: 0.0788 - val_accuracy: 0.9737 - lr: 5.0000e-06
# Epoch 28/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9793
# Epoch 28: val_loss did not improve from 0.07673
# 108/108 [==============================] - 84s 775ms/step - loss: 0.0659 - accuracy: 0.9793 - val_loss: 0.0790 - val_accuracy: 0.9693 - lr: 2.5000e-06
# Epoch 29/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9857
# Epoch 29: val_loss improved from 0.07673 to 0.07625, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 783ms/step - loss: 0.0493 - accuracy: 0.9857 - val_loss: 0.0763 - val_accuracy: 0.9737 - lr: 2.5000e-06
# Epoch 30/30
# 108/108 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9837
# Epoch 30: val_loss improved from 0.07625 to 0.07538, saving model to ../models\best_model3.h5
# 108/108 [==============================] - 85s 791ms/step - loss: 0.0505 - accuracy: 0.9837 - val_loss: 0.0754 - val_accuracy: 0.9737 - lr: 2.5000e-06

# %%
# ==========================================
# STEP 8: Save final model & metadata
# ==========================================

# --- GABUNGKAN HISTORY (fase 1 + fase 2) ---
# agar grafik & statistik mencakup seluruh pelatihan
combined_history = {}
for key in history.history.keys():
    combined_history[key] = history.history[key] + history_finetune.history.get(key, [])

# --- Hitung rata-rata akurasi dari fase akhir (fine-tuning) ---
train_acc_avg = np.mean(history_finetune.history.get('accuracy', history.history.get('accuracy', [-1])))
val_acc_avg   = np.mean(history_finetune.history.get('val_accuracy', history.history.get('val_accuracy', [-1])))

train_acc_int = int(train_acc_avg * 100)
val_acc_int = int(val_acc_avg * 100)

# create versioned folder like before
pattern = re.compile(r"model-rdc-(\d+).(\d+)")
existing_dirs = [d for d in os.listdir(MODEL_DIR) if os.path.isdir(os.path.join(MODEL_DIR, d))]
model_id = MODEL_ID
versions = []
for d in existing_dirs:
    m = pattern.match(d)
    if m and int(m.group(1)) == model_id:
        versions.append(int(m.group(2)))
next_version = max(versions) + 1 if versions else 1

# --- Buat folder penyimpanan baru ---
model_fname = f"model-rdc-{model_id}.{next_version}"
save_dir = os.path.join(MODEL_DIR, model_fname)
os.makedirs(save_dir, exist_ok=True)

# --- Simpan model final (setelah fine-tuning) ---
final_model_path = os.path.join(save_dir, f"model.h5")
model.save(final_model_path)

# --- Simpan label kelas ---
labels = {v: k for k, v in train_generator.class_indices.items()}
with open(os.path.join(save_dir, "labels.json"), "w") as f:
    json.dump(labels, f, indent=4)

# --- Simpan ringkasan metadata model ---
summary = {
    "model_id": model_id,
    "version": next_version,
    "model_name": model_fname,
    "model_use": MODEL_NAME,
    "train_acc_avg": round(float(train_acc_avg) * 100, 2),
    "val_acc_avg": round(float(val_acc_avg) * 100, 2),
    "epochs_phase1": len(history.history.get('accuracy', [])),
    "epochs_phase2": len(history_finetune.history.get('accuracy', [])),
    "model_path": final_model_path
}
with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

def to_serializable(obj):
    """Konversi semua numpy type ke tipe Python biasa agar bisa di-dump ke JSON"""
    if isinstance(obj, (np.float32, np.float64)):
        return float(obj)
    if isinstance(obj, (np.int32, np.int64)):
        return int(obj)
    if isinstance(obj, (np.ndarray, list)):
        return [to_serializable(x) for x in obj]
    if isinstance(obj, dict):
        return {k: to_serializable(v) for k, v in obj.items()}
    return obj


# --- Simpan riwayat pelatihan (fase 1, fase 2, dan gabungan) ---
with open(os.path.join(save_dir, "history_phase1.json"), "w") as f:
    json.dump(to_serializable(history.history), f, indent=4)

with open(os.path.join(save_dir, "history_finetune.json"), "w") as f:
    json.dump(to_serializable(history_finetune.history), f, indent=4)

with open(os.path.join(save_dir, "history_combined.json"), "w") as f:
    json.dump(to_serializable(combined_history), f, indent=4)


print(f"📁 Semua file metadata dan history disimpan di: {save_dir}")
# Out:
# 📁 Semua file metadata dan history disimpan di: ../models\model-rdc-1.1

# %%
# ==========================================
# STEP 8: Save final model & metadata
# ==========================================

# --- GABUNGKAN HISTORY (fase 1 + fase 2) ---
# agar grafik & statistik mencakup seluruh pelatihan
combined_history = {}
for key in history.history.keys():
    combined_history[key] = history.history[key] + history_finetune.history.get(key, [])

# --- Hitung rata-rata akurasi dari fase akhir (fine-tuning) ---
train_acc_avg = np.mean(history_finetune.history.get('accuracy', history.history.get('accuracy', [-1])))
val_acc_avg   = np.mean(history_finetune.history.get('val_accuracy', history.history.get('val_accuracy', [-1])))

train_acc_int = int(train_acc_avg * 100)
val_acc_int = int(val_acc_avg * 100)

# create versioned folder like before
pattern = re.compile(r"Model-RDC-(\d+).(\d+)")
existing_dirs = [d for d in os.listdir(MODEL_DIR) if os.path.isdir(os.path.join(MODEL_DIR, d))]
model_id = MODEL_ID
versions = []
for d in existing_dirs:
    m = pattern.match(d)
    if m and int(m.group(1)) == model_id:
        versions.append(int(m.group(2)))
next_version = max(versions) + 1 if versions else 1

# --- Buat folder penyimpanan baru ---
model_fname = f"Model-RDC-{model_id}.{next_version}"
save_dir = os.path.join(MODEL_DIR, model_fname)
os.makedirs(save_dir, exist_ok=True)

# --- Simpan model final (setelah fine-tuning) ---
final_model_path = os.path.join(save_dir, f"model.h5")
model.save(final_model_path)

# --- Simpan label kelas ---
labels = {v: k for k, v in train_generator.class_indices.items()}
with open(os.path.join(save_dir, "labels.json"), "w") as f:
    json.dump(labels, f, indent=4)

# --- Simpan ringkasan metadata model ---
summary = {
    "model_id": model_id,
    "version": next_version,
    "model_name": model_fname,
    "model_use": MODEL_NAME,
    "train_acc_avg": round(float(train_acc_avg) * 100, 2),
    "val_acc_avg": round(float(val_acc_avg) * 100, 2),
    "epochs_phase1": len(history.history.get('accuracy', [])),
    "epochs_phase2": len(history_finetune.history.get('accuracy', [])),
    "model_path": final_model_path
}
with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

def to_serializable(obj):
    """Konversi semua numpy type ke tipe Python biasa agar bisa di-dump ke JSON"""
    if isinstance(obj, (np.float32, np.float64)):
        return float(obj)
    if isinstance(obj, (np.int32, np.int64)):
        return int(obj)
    if isinstance(obj, (np.ndarray, list)):
        return [to_serializable(x) for x in obj]
    if isinstance(obj, dict):
        return {k: to_serializable(v) for k, v in obj.items()}
    return obj


# --- Simpan riwayat pelatihan (fase 1, fase 2, dan gabungan) ---
with open(os.path.join(save_dir, "history_phase1.json"), "w") as f:
    json.dump(to_serializable(history.history), f, indent=4)

with open(os.path.join(save_dir, "history_finetune.json"), "w") as f:
    json.dump(to_serializable(history_finetune.history), f, indent=4)

with open(os.path.join(save_dir, "history_combined.json"), "w") as f:
    json.dump(to_serializable(combined_history), f, indent=4)


print(f"📁 Semua file metadata dan history disimpan di: {save_dir}")
# Out:
# 📁 Semua file metadata dan history disimpan di: ../models\Model-RDC-3.1

# %%
# ==========================================
# STEP 9: Plot & save metrics (FINAL)
# ==========================================

# Gunakan combined_history dari STEP 8
acc      = combined_history.get('accuracy', [])
val_acc  = combined_history.get('val_accuracy', [])
loss     = combined_history.get('loss', [])
val_loss = combined_history.get('val_loss', [])

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

# --- Plot Accuracy ---
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Accuracy', marker='o')
plt.plot(epochs_range, val_acc, label='Val Accuracy', marker='s')
plt.title("Training & Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# --- Plot Loss ---
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Loss', marker='o')
plt.plot(epochs_range, val_loss, label='Val Loss', marker='s')
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()

# --- Simpan grafik ---
metrics_path = os.path.join(save_dir, "metrics.png")
plt.savefig(metrics_path)
plt.show()
plt.close()

print(f"📈 Grafik akurasi & loss disimpan di: {metrics_path}")
# Out:
# 📈 Grafik akurasi & loss disimpan di: ../models\Model-RDC-3.1\metrics.png

# %%
# ==========================================
# STEP 10: Evaluation (validation set)
# ==========================================
print("\n🚀 Evaluasi Model pada Validation Set...")

# --- Reset generator agar prediksi berurutan ---
val_generator.reset()

# --- Prediksi ---
y_pred = model.predict(val_generator, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

# --- Label kelas ---
class_labels = list(val_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Validation):")
report_val = classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_val_path = os.path.join(save_dir, "evaluation_val.json")
with open(eval_val_path, "w") as f:
    json.dump(report_val, f, indent=4)
print(f"✅ Laporan evaluasi validasi disimpan: {eval_val_path}")

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')

# --- Simpan confusion matrix ---
cm_val_path = os.path.join(save_dir, "confusion_matrix_val.png")
plt.tight_layout()
plt.savefig(cm_val_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix validasi disimpan di: {cm_val_path}")
# Out:
# 🚀 Evaluasi Model pada Validation Set...
#
# 📊 Classification Report (Validation):
#               precision    recall  f1-score   support
#
#         alur       1.00      0.80      0.89         5
#       lubang       0.97      0.98      0.97       116
#        retak       0.98      0.97      0.97        93
#  tidak_rusak       1.00      1.00      1.00        14
#
#     accuracy                           0.97       228
#    macro avg       0.99      0.94      0.96       228
# weighted avg       0.97      0.97      0.97       228
#
# ✅ Laporan evaluasi validasi disimpan: ../models\Model-RDC-3.1\evaluation_val.json
# 🧩 Confusion matrix validasi disimpan di: ../models\Model-RDC-3.1\confusion_matrix_val.png

# %%
# ==========================================
# STEP 11: Testing (test set)
# ==========================================
print("\n🚀 Evaluasi Model pada Test Set...")

# --- Reset generator ---
test_generator.reset()

# --- Evaluasi langsung ---
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"\n📈 Test Accuracy: {test_acc*100:.2f}%  |  Test Loss: {test_loss:.4f}")

# --- Prediksi ---
y_pred_test = model.predict(test_generator, verbose=0)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_true_test = test_generator.classes

# --- Label kelas ---
class_labels = list(test_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Test):")
report_test = classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_test_path = os.path.join(save_dir, "evaluation_test.json")
with open(eval_test_path, "w") as f:
    json.dump(report_test, f, indent=4)
print(f"✅ Laporan evaluasi testing disimpan: {eval_test_path}")

# --- Confusion Matrix ---
cm_test = confusion_matrix(y_true_test, y_pred_test_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Greens',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Test Set')

# --- Simpan confusion matrix ---
cm_test_path = os.path.join(save_dir, "confusion_matrix_test.png")
plt.tight_layout()
plt.savefig(cm_test_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix testing disimpan di: {cm_test_path}")

# --- Simpan ringkasan hasil test ke summary.json ---
summary["test_accuracy"] = round(float(test_acc) * 100, 2)
summary["test_loss"] = round(float(test_loss), 4)

with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

print(f"📘 Summary diperbarui dengan hasil test: {os.path.join(save_dir, 'summary.json')}")
# Out:
# 🚀 Evaluasi Model pada Test Set...
#
# 📈 Test Accuracy: 98.62%  |  Test Loss: 0.0607
#
# 📊 Classification Report (Test):
#               precision    recall  f1-score   support
#
#         alur       0.86      1.00      0.92         6
#       lubang       0.98      1.00      0.99       112
#        retak       1.00      0.98      0.99        90
#  tidak_rusak       1.00      0.90      0.95        10
#
#     accuracy                           0.99       218
#    macro avg       0.96      0.97      0.96       218
# weighted avg       0.99      0.99      0.99       218
#
# ✅ Laporan evaluasi testing disimpan: ../models\Model-RDC-3.1\evaluation_test.json
# 🧩 Confusion matrix testing disimpan di: ../models\Model-RDC-3.1\confusion_matrix_test.png
# 📘 Summary diperbarui dengan hasil test: ../models\Model-RDC-3.1\summary.json
