# %%
import pandas as pd
from tensorflow.keras.applications import MobileNetV2

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False)

# Ambil informasi setiap layer
layer_info = []
for i, layer in enumerate(base_model.layers):
    try:
        output_shape = layer.output.shape
    except:
        output_shape = "N/A"
    layer_info.append({
        "Index": i,
        "Nama Layer": layer.name,
        "Trainable": layer.trainable,
        "Output Shape": str(output_shape)
    })

# Konversi ke DataFrame biar rapi
df_layers = pd.DataFrame(layer_info)

# ⿤ Tampilkan semua baris tanpa dipotong
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# ⿥ Cetak tabel lengkap
df_layers
# Out:
# C:\Users\riyan\AppData\Local\Temp\ipykernel_15856\1396359857.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False)
#      Index                    Nama Layer  Trainable              Output Shape
# 0        0                 input_layer_8       True     (None, None, None, 3)
# 1        1                         Conv1       True    (None, None, None, 32)
# 2        2                      bn_Conv1       True    (None, None, None, 32)
# 3        3                    Conv1_relu       True    (None, None, None, 32)
# 4        4       expanded_conv_depthwise       True    (None, None, None, 32)
# 5        5    expanded_conv_depthwise_BN       True    (None, None, None, 32)
# 6        6  expanded_conv_depthwise_relu       True    (None, None, None, 32)
# 7        7         expanded_conv_project       True    (None, None, None, 16)
# 8        8      expanded_conv_project_BN       True    (None, None, None, 16)
# 9        9                block_1_expand       True    (None, None, None, 96)
# 10      10             block_1_expand_BN       True    (None, None, None, 96)
# 11      11           block_1_expand_relu       True    (None, None, None, 96)
# 12      12                   block_1_pad       True    (None, None, None, 96)
# 13      13             block_1_depthwise       True    (None, None, None, 96)
# 14      14          block_1_depthwise_BN       True    (None, None, None, 96)
# 15      15        block_1_depthwise_relu       True    (None, None, None, 96)
# 16      16               block_1_project       True    (None, None, None, 24)
# 17      17            block_1_project_BN       True    (None, None, None, 24)
# 18      18                block_2_expand       True   (None, None, None, 144)
# 19      19             block_2_expand_BN       True   (None, None, None, 144)
# 20      20           block_2_expand_relu       True   (None, None, None, 144)
# 21      21             block_2_depthwise       True   (None, None, None, 144)
# 22      22          block_2_depthwise_BN       True   (None, None, None, 144)
# 23      23        block_2_depthwise_relu       True   (None, None, None, 144)
# 24      24               block_2_project       True    (None, None, None, 24)
# 25      25            block_2_project_BN       True    (None, None, None, 24)
# 26      26                   block_2_add       True    (None, None, None, 24)
# 27      27                block_3_expand       True   (None, None, None, 144)
# 28      28             block_3_expand_BN       True   (None, None, None, 144)
# 29      29           block_3_expand_relu       True   (None, None, None, 144)
# 30      30                   block_3_pad       True   (None, None, None, 144)
# 31      31             block_3_depthwise       True   (None, None, None, 144)
# 32      32          block_3_depthwise_BN       True   (None, None, None, 144)
# 33      33        block_3_depthwise_relu       True   (None, None, None, 144)
# 34      34               block_3_project       True    (None, None, None, 32)
# 35      35            block_3_project_BN       True    (None, None, None, 32)
# 36      36                block_4_expand       True   (None, None, None, 192)
# 37      37             block_4_expand_BN       True   (None, None, None, 192)
# 38      38           block_4_expand_relu       True   (None, None, None, 192)
# 39      39             block_4_depthwise       True   (None, None, None, 192)
# 40      40          block_4_depthwise_BN       True   (None, None, None, 192)
# 41      41        block_4_depthwise_relu       True   (None, None, None, 192)
# 42      42               block_4_project       True    (None, None, None, 32)
# 43      43            block_4_project_BN       True    (None, None, None, 32)
# 44      44                   block_4_add       True    (None, None, None, 32)
# 45      45                block_5_expand       True   (None, None, None, 192)
# 46      46             block_5_expand_BN       True   (None, None, None, 192)
# 47      47           block_5_expand_relu       True   (None, None, None, 192)
# 48      48             block_5_depthwise       True   (None, None, None, 192)
# 49      49          block_5_depthwise_BN       True   (None, None, None, 192)
# 50      50        block_5_depthwise_relu       True   (None, None, None, 192)
# 51      51               block_5_project       True    (None, None, None, 32)
# 52      52            block_5_project_BN       True    (None, None, None, 32)
# 53      53                   block_5_add       True    (None, None, None, 32)
# 54      54                block_6_expand       True   (None, None, None, 192)
# 55      55             block_6_expand_BN       True   (None, None, None, 192)
# 56      56           block_6_expand_relu       True   (None, None, None, 192)
# 57      57                   block_6_pad       True   (None, None, None, 192)
# 58      58             block_6_depthwise       True   (None, None, None, 192)
# 59      59          block_6_depthwise_BN       True   (None, None, None, 192)
# 60      60        block_6_depthwise_relu       True   (None, None, None, 192)
# 61      61               block_6_project       True    (None, None, None, 64)
# 62      62            block_6_project_BN       True    (None, None, None, 64)
# 63      63                block_7_expand       True   (None, None, None, 384)
# 64      64             block_7_expand_BN       True   (None, None, None, 384)
# 65      65           block_7_expand_relu       True   (None, None, None, 384)
# 66      66             block_7_depthwise       True   (None, None, None, 384)
# 67      67          block_7_depthwise_BN       True   (None, None, None, 384)
# 68      68        block_7_depthwise_relu       True   (None, None, None, 384)
# 69      69               block_7_project       True    (None, None, None, 64)
# 70      70            block_7_project_BN       True    (None, None, None, 64)
# 71      71                   block_7_add       True    (None, None, None, 64)
# 72      72                block_8_expand       True   (None, None, None, 384)
# 73      73             block_8_expand_BN       True   (None, None, None, 384)
# 74      74           block_8_expand_relu       True   (None, None, None, 384)
# 75      75             block_8_depthwise       True   (None, None, None, 384)
# 76      76          block_8_depthwise_BN       True   (None, None, None, 384)
# 77      77        block_8_depthwise_relu       True   (None, None, None, 384)
# 78      78               block_8_project       True    (None, None, None, 64)
# 79      79            block_8_project_BN       True    (None, None, None, 64)
# 80      80                   block_8_add       True    (None, None, None, 64)
# 81      81                block_9_expand       True   (None, None, None, 384)
# 82      82             block_9_expand_BN       True   (None, None, None, 384)
# 83      83           block_9_expand_relu       True   (None, None, None, 384)
# 84      84             block_9_depthwise       True   (None, None, None, 384)
# 85      85          block_9_depthwise_BN       True   (None, None, None, 384)
# 86      86        block_9_depthwise_relu       True   (None, None, None, 384)
# 87      87               block_9_project       True    (None, None, None, 64)
# 88      88            block_9_project_BN       True    (None, None, None, 64)
# 89      89                   block_9_add       True    (None, None, None, 64)
# 90      90               block_10_expand       True   (None, None, None, 384)
# 91      91            block_10_expand_BN       True   (None, None, None, 384)
# 92      92          block_10_expand_relu       True   (None, None, None, 384)
# 93      93            block_10_depthwise       True   (None, None, None, 384)
# 94      94         block_10_depthwise_BN       True   (None, None, None, 384)
# 95      95       block_10_depthwise_relu       True   (None, None, None, 384)
# 96      96              block_10_project       True    (None, None, None, 96)
# 97      97           block_10_project_BN       True    (None, None, None, 96)
# 98      98               block_11_expand       True   (None, None, None, 576)
# 99      99            block_11_expand_BN       True   (None, None, None, 576)
# 100    100          block_11_expand_relu       True   (None, None, None, 576)
# 101    101            block_11_depthwise       True   (None, None, None, 576)
# 102    102         block_11_depthwise_BN       True   (None, None, None, 576)
# 103    103       block_11_depthwise_relu       True   (None, None, None, 576)
# 104    104              block_11_project       True    (None, None, None, 96)
# 105    105           block_11_project_BN       True    (None, None, None, 96)
# 106    106                  block_11_add       True    (None, None, None, 96)
# 107    107               block_12_expand       True   (None, None, None, 576)
# 108    108            block_12_expand_BN       True   (None, None, None, 576)
# 109    109          block_12_expand_relu       True   (None, None, None, 576)
# 110    110            block_12_depthwise       True   (None, None, None, 576)
# 111    111         block_12_depthwise_BN       True   (None, None, None, 576)
# 112    112       block_12_depthwise_relu       True   (None, None, None, 576)
# 113    113              block_12_project       True    (None, None, None, 96)
# 114    114           block_12_project_BN       True    (None, None, None, 96)
# 115    115                  block_12_add       True    (None, None, None, 96)
# 116    116               block_13_expand       True   (None, None, None, 576)
# 117    117            block_13_expand_BN       True   (None, None, None, 576)
# 118    118          block_13_expand_relu       True   (None, None, None, 576)
# 119    119                  block_13_pad       True   (None, None, None, 576)
# 120    120            block_13_depthwise       True   (None, None, None, 576)
# 121    121         block_13_depthwise_BN       True   (None, None, None, 576)
# 122    122       block_13_depthwise_relu       True   (None, None, None, 576)
# 123    123              block_13_project       True   (None, None, None, 160)
# 124    124           block_13_project_BN       True   (None, None, None, 160)
# 125    125               block_14_expand       True   (None, None, None, 960)
# 126    126            block_14_expand_BN       True   (None, None, None, 960)
# 127    127          block_14_expand_relu       True   (None, None, None, 960)
# 128    128            block_14_depthwise       True   (None, None, None, 960)
# 129    129         block_14_depthwise_BN       True   (None, None, None, 960)
# 130    130       block_14_depthwise_relu       True   (None, None, None, 960)
# 131    131              block_14_project       True   (None, None, None, 160)
# 132    132           block_14_project_BN       True   (None, None, None, 160)
# 133    133                  block_14_add       True   (None, None, None, 160)
# 134    134               block_15_expand       True   (None, None, None, 960)
# 135    135            block_15_expand_BN       True   (None, None, None, 960)
# 136    136          block_15_expand_relu       True   (None, None, None, 960)
# 137    137            block_15_depthwise       True   (None, None, None, 960)
# 138    138         block_15_depthwise_BN       True   (None, None, None, 960)
# 139    139       block_15_depthwise_relu       True   (None, None, None, 960)
# 140    140              block_15_project       True   (None, None, None, 160)
# 141    141           block_15_project_BN       True   (None, None, None, 160)
# 142    142                  block_15_add       True   (None, None, None, 160)
# 143    143               block_16_expand       True   (None, None, None, 960)
# 144    144            block_16_expand_BN       True   (None, None, None, 960)
# 145    145          block_16_expand_relu       True   (None, None, None, 960)
# 146    146            block_16_depthwise       True   (None, None, None, 960)
# 147    147         block_16_depthwise_BN       True   (None, None, None, 960)
# 148    148       block_16_depthwise_relu       True   (None, None, None, 960)
# 149    149              block_16_project       True   (None, None, None, 320)
# 150    150           block_16_project_BN       True   (None, None, None, 320)
# 151    151                        Conv_1       True  (None, None, None, 1280)
# 152    152                     Conv_1_bn       True  (None, None, None, 1280)
# 153    153                      out_relu       True  (None, None, None, 1280)
