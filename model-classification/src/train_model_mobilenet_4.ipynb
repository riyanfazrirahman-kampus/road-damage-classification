# %%
import os
import re
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from collections import Counter

from sklearn.metrics import classification_report, confusion_matrix

# %%
# ==========================================
# STEP 0: PARAMETERS & PATHS (sesuaikan)
# ==========================================
PROCESSED_DIR = "../dataset_processed_aug"  # output: train/ val/ test/ per kelas
MODEL_DIR = "../models"
MODEL_ID = 4

IMG_SIZE = (224, 224)   # tuple: target_size untuk flow_from_directory
IMG_SIDE = IMG_SIZE[0]  # integer untuk fungsi make_square
BATCH_SIZE = 16

# Training
TRAIN_EPOCHS = 50
TRAIN_DROPOUT = 0.5
TRAIN_LEARNING_RATE = 0.0005

# Fine-Tuning
TUNING_EPOCHS = 30
TUNING_LEARNING_RATE = 1e-5

os.makedirs(MODEL_DIR, exist_ok=True)

# %%
# ==========================================
# TABEL HORIZONTAL
# ==========================================
params = {
    "MODEL": MODEL_ID,
    "LEARNING_RATE": TRAIN_LEARNING_RATE,
    "BATCH": BATCH_SIZE,
    "EPOCHS": TRAIN_EPOCHS,
    "DROPOUT": TRAIN_DROPOUT,
    "AUGMENTASI": True
}

pd.DataFrame([params])
# Out:
#    MODEL  LEARNING_RATE  BATCH  EPOCHS  DROPOUT  AUGMENTASI
# 0      4         0.0005     16      50      0.5        True

# %%
# ==========================================
# STEP 4: Data generators
# - train: augmentation + rescale
# - val/test: hanya rescale
# ==========================================

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)

valtest_datagen = ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
)

val_generator = valtest_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "val"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = valtest_datagen.flow_from_directory(
    os.path.join(PROCESSED_DIR, "test"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 3429 images belonging to 4 classes.
# Found 228 images belonging to 4 classes.
# Found 218 images belonging to 4 classes.

# %%
print("Generators siap:")
print(" - train samples:", train_generator.samples)
print(" - val samples:", val_generator.samples)
print(" - test samples:", test_generator.samples)
print("Classes:", train_generator.class_indices)

X_batch, Y_batch = next(train_generator)

print(X_batch.shape)  
print(Y_batch.shape)  # contoh: (32, jumlah_kelas)
print(Y_batch[0])     # label one-hot gambar pertama
# Out:
# Generators siap:
#  - train samples: 3429
#  - val samples: 228
#  - test samples: 218
# Classes: {'alur': 0, 'lubang': 1, 'retak': 2, 'tidak_rusak': 3}
# (16, 224, 224, 3)
# (16, 4)
# [0. 0. 0. 1.]

# %%
# ==========================================
# (Optional) print counts per class for sanity check
# ==========================================

print("\nCounts per class (train):")
train_counts = Counter([os.path.split(f)[0] for f in train_generator.filenames])
for cls, idx in train_generator.class_indices.items():
    print(f" - {cls}: {train_counts[cls]}")

print("\nCounts per class (val):")
val_counts = Counter([os.path.split(f)[0] for f in val_generator.filenames])
for cls, idx in val_generator.class_indices.items():
    print(f" - {cls}: {val_counts[cls]}")

print("\nCounts per class (test):")
val_counts = Counter([os.path.split(f)[0] for f in test_generator.filenames])
for cls, idx in val_generator.class_indices.items():
    print(f" - {cls}: {val_counts[cls]}")
# Out:
# Counts per class (train):
#  - alur: 857
#  - lubang: 858
#  - retak: 857
#  - tidak_rusak: 857
#
# Counts per class (val):
#  - alur: 5
#  - lubang: 116
#  - retak: 93
#  - tidak_rusak: 14
#
# Counts per class (test):
#  - alur: 6
#  - lubang: 112
#  - retak: 90
#  - tidak_rusak: 10

# %%
# ==========================================
# STEP 5: Build model (MobileNetV2 transfer learning)
# ==========================================

num_classes = train_generator.num_classes

MODEL_NAME = "MobileNetV2"
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIDE, IMG_SIDE, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(TRAIN_DROPOUT)(x)
preds = Dense(num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=preds)

# freeze base
for layer in base_model.layers:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=TRAIN_LEARNING_RATE), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

print("\nModel siap. Jumlah kelas:", num_classes)
# Out:
# Model siap. Jumlah kelas: 4

# %%
# ==========================================
# STEP 6: Callbacks 
# ==========================================

checkpoint_path = os.path.join(MODEL_DIR, "best_model4.h5")
callbacks = [
    ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_loss', verbose=1),
    EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
]

# %%
# ==========================================
# STEP 7: Training
# ==========================================

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=TRAIN_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 215/215 [==============================] - ETA: 0s - loss: 1.0677 - accuracy: 0.5771
# Epoch 1: val_loss improved from inf to 0.41237, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 51s 225ms/step - loss: 1.0677 - accuracy: 0.5771 - val_loss: 0.4124 - val_accuracy: 0.9079 - lr: 5.0000e-04
# Epoch 2/50
# 215/215 [==============================] - ETA: 0s - loss: 0.6155 - accuracy: 0.7775
# Epoch 2: val_loss improved from 0.41237 to 0.31088, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 182ms/step - loss: 0.6155 - accuracy: 0.7775 - val_loss: 0.3109 - val_accuracy: 0.9254 - lr: 5.0000e-04
# Epoch 3/50
# 215/215 [==============================] - ETA: 0s - loss: 0.5046 - accuracy: 0.8125
# Epoch 3: val_loss improved from 0.31088 to 0.24611, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 181ms/step - loss: 0.5046 - accuracy: 0.8125 - val_loss: 0.2461 - val_accuracy: 0.9474 - lr: 5.0000e-04
# Epoch 4/50
# 215/215 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.8486
# Epoch 4: val_loss improved from 0.24611 to 0.21480, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 182ms/step - loss: 0.4253 - accuracy: 0.8486 - val_loss: 0.2148 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 5/50
# 215/215 [==============================] - ETA: 0s - loss: 0.3899 - accuracy: 0.8571
# Epoch 5: val_loss did not improve from 0.21480
# 215/215 [==============================] - 40s 187ms/step - loss: 0.3899 - accuracy: 0.8571 - val_loss: 0.2287 - val_accuracy: 0.9298 - lr: 5.0000e-04
# Epoch 6/50
# 215/215 [==============================] - ETA: 0s - loss: 0.3629 - accuracy: 0.8731
# Epoch 6: val_loss improved from 0.21480 to 0.19982, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 180ms/step - loss: 0.3629 - accuracy: 0.8731 - val_loss: 0.1998 - val_accuracy: 0.9474 - lr: 5.0000e-04
# Epoch 7/50
# 215/215 [==============================] - ETA: 0s - loss: 0.3623 - accuracy: 0.8720
# Epoch 7: val_loss did not improve from 0.19982
# 215/215 [==============================] - 48s 223ms/step - loss: 0.3623 - accuracy: 0.8720 - val_loss: 0.2099 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 8/50
# 215/215 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8825
# Epoch 8: val_loss did not improve from 0.19982
# 215/215 [==============================] - 54s 249ms/step - loss: 0.3265 - accuracy: 0.8825 - val_loss: 0.2026 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 9/50
# 215/215 [==============================] - ETA: 0s - loss: 0.3164 - accuracy: 0.8898
# Epoch 9: val_loss improved from 0.19982 to 0.17783, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 52s 243ms/step - loss: 0.3164 - accuracy: 0.8898 - val_loss: 0.1778 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 10/50
# 215/215 [==============================] - ETA: 0s - loss: 0.3040 - accuracy: 0.8938
# Epoch 10: val_loss did not improve from 0.17783
# 215/215 [==============================] - 45s 206ms/step - loss: 0.3040 - accuracy: 0.8938 - val_loss: 0.1857 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 11/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.8982
# Epoch 11: val_loss did not improve from 0.17783
# 215/215 [==============================] - 44s 203ms/step - loss: 0.2897 - accuracy: 0.8982 - val_loss: 0.1945 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 12/50
# 215/215 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8901
# Epoch 12: val_loss improved from 0.17783 to 0.16795, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 40s 186ms/step - loss: 0.3000 - accuracy: 0.8901 - val_loss: 0.1679 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 13/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.8973
# Epoch 13: val_loss improved from 0.16795 to 0.16460, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 40s 186ms/step - loss: 0.2826 - accuracy: 0.8973 - val_loss: 0.1646 - val_accuracy: 0.9561 - lr: 5.0000e-04
# Epoch 14/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2766 - accuracy: 0.8982
# Epoch 14: val_loss did not improve from 0.16460
# 215/215 [==============================] - 39s 183ms/step - loss: 0.2766 - accuracy: 0.8982 - val_loss: 0.1724 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 15/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8915
# Epoch 15: val_loss did not improve from 0.16460
# 215/215 [==============================] - 39s 181ms/step - loss: 0.2920 - accuracy: 0.8915 - val_loss: 0.1925 - val_accuracy: 0.9386 - lr: 5.0000e-04
# Epoch 16/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2794 - accuracy: 0.9026
# Epoch 16: val_loss did not improve from 0.16460
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 215/215 [==============================] - 39s 182ms/step - loss: 0.2794 - accuracy: 0.9026 - val_loss: 0.1763 - val_accuracy: 0.9430 - lr: 5.0000e-04
# Epoch 17/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.8927
# Epoch 17: val_loss did not improve from 0.16460
# 215/215 [==============================] - 41s 189ms/step - loss: 0.2873 - accuracy: 0.8927 - val_loss: 0.1693 - val_accuracy: 0.9474 - lr: 2.5000e-04
# Epoch 18/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.9038
# Epoch 18: val_loss did not improve from 0.16460
# 215/215 [==============================] - 39s 181ms/step - loss: 0.2732 - accuracy: 0.9038 - val_loss: 0.1661 - val_accuracy: 0.9649 - lr: 2.5000e-04
# Epoch 19/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9076
# Epoch 19: val_loss did not improve from 0.16460
# Restoring model weights from the end of the best epoch: 13.
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 215/215 [==============================] - 39s 181ms/step - loss: 0.2570 - accuracy: 0.9076 - val_loss: 0.1648 - val_accuracy: 0.9561 - lr: 2.5000e-04
# Epoch 19: early stopping

# %%
# ==========================================
# STEP 8: Fine-tuning (fase kedua)
# ==========================================

# Unfreeze 50 layer terakhir dari base model
for layer in base_model.layers[-50:]:
    layer.trainable = True

# Compile ulang dengan learning rate lebih kecil
model.compile(
    optimizer=Adam(learning_rate=TUNING_LEARNING_RATE),  # LR kecil untuk fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Latih ulang model (fine-tuning)
history_finetune = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=TUNING_EPOCHS,
   callbacks=callbacks
)
# Out:
# Epoch 1/30
# 215/215 [==============================] - ETA: 0s - loss: 0.7428 - accuracy: 0.7568
# Epoch 1: val_loss did not improve from 0.16460
# 215/215 [==============================] - 43s 182ms/step - loss: 0.7428 - accuracy: 0.7568 - val_loss: 0.1853 - val_accuracy: 0.9386 - lr: 1.0000e-05
# Epoch 2/30
# 215/215 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.8495
# Epoch 2: val_loss did not improve from 0.16460
# 215/215 [==============================] - 39s 180ms/step - loss: 0.4138 - accuracy: 0.8495 - val_loss: 0.2149 - val_accuracy: 0.9211 - lr: 1.0000e-05
# Epoch 3/30
# 215/215 [==============================] - ETA: 0s - loss: 0.3503 - accuracy: 0.8772
# Epoch 3: val_loss did not improve from 0.16460
# 215/215 [==============================] - 40s 187ms/step - loss: 0.3503 - accuracy: 0.8772 - val_loss: 0.2029 - val_accuracy: 0.9342 - lr: 1.0000e-05
# Epoch 4/30
# 215/215 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.8944
# Epoch 4: val_loss did not improve from 0.16460
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 215/215 [==============================] - 39s 181ms/step - loss: 0.2924 - accuracy: 0.8944 - val_loss: 0.1872 - val_accuracy: 0.9298 - lr: 1.0000e-05
# Epoch 5/30
# 215/215 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.9038
# Epoch 5: val_loss improved from 0.16460 to 0.15206, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 180ms/step - loss: 0.2713 - accuracy: 0.9038 - val_loss: 0.1521 - val_accuracy: 0.9474 - lr: 5.0000e-06
# Epoch 6/30
# 215/215 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.9157
# Epoch 6: val_loss improved from 0.15206 to 0.13792, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 38s 179ms/step - loss: 0.2361 - accuracy: 0.9157 - val_loss: 0.1379 - val_accuracy: 0.9430 - lr: 5.0000e-06
# Epoch 7/30
# 215/215 [==============================] - ETA: 0s - loss: 0.2389 - accuracy: 0.9137
# Epoch 7: val_loss improved from 0.13792 to 0.12322, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 180ms/step - loss: 0.2389 - accuracy: 0.9137 - val_loss: 0.1232 - val_accuracy: 0.9386 - lr: 5.0000e-06
# Epoch 8/30
# 215/215 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.9198
# Epoch 8: val_loss improved from 0.12322 to 0.11599, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 180ms/step - loss: 0.2386 - accuracy: 0.9198 - val_loss: 0.1160 - val_accuracy: 0.9474 - lr: 5.0000e-06
# Epoch 9/30
# 215/215 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9239
# Epoch 9: val_loss improved from 0.11599 to 0.10756, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 181ms/step - loss: 0.2162 - accuracy: 0.9239 - val_loss: 0.1076 - val_accuracy: 0.9561 - lr: 5.0000e-06
# Epoch 10/30
# 215/215 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9306
# Epoch 10: val_loss improved from 0.10756 to 0.10134, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 180ms/step - loss: 0.2036 - accuracy: 0.9306 - val_loss: 0.1013 - val_accuracy: 0.9561 - lr: 5.0000e-06
# Epoch 11/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9338
# Epoch 11: val_loss improved from 0.10134 to 0.09975, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 41s 189ms/step - loss: 0.1879 - accuracy: 0.9338 - val_loss: 0.0998 - val_accuracy: 0.9561 - lr: 5.0000e-06
# Epoch 12/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9318
# Epoch 12: val_loss improved from 0.09975 to 0.09552, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 183ms/step - loss: 0.1932 - accuracy: 0.9318 - val_loss: 0.0955 - val_accuracy: 0.9561 - lr: 5.0000e-06
# Epoch 13/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9425
# Epoch 13: val_loss improved from 0.09552 to 0.09349, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 40s 184ms/step - loss: 0.1716 - accuracy: 0.9425 - val_loss: 0.0935 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 14/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9475
# Epoch 14: val_loss did not improve from 0.09349
# 215/215 [==============================] - 38s 177ms/step - loss: 0.1686 - accuracy: 0.9475 - val_loss: 0.0942 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 15/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9434
# Epoch 15: val_loss improved from 0.09349 to 0.09032, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 181ms/step - loss: 0.1582 - accuracy: 0.9434 - val_loss: 0.0903 - val_accuracy: 0.9649 - lr: 5.0000e-06
# Epoch 16/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9376
# Epoch 16: val_loss improved from 0.09032 to 0.08974, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 182ms/step - loss: 0.1758 - accuracy: 0.9376 - val_loss: 0.0897 - val_accuracy: 0.9561 - lr: 5.0000e-06
# Epoch 17/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1480 - accuracy: 0.9493
# Epoch 17: val_loss improved from 0.08974 to 0.08771, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 40s 185ms/step - loss: 0.1480 - accuracy: 0.9493 - val_loss: 0.0877 - val_accuracy: 0.9561 - lr: 5.0000e-06
# Epoch 18/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9545
# Epoch 18: val_loss improved from 0.08771 to 0.08759, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 183ms/step - loss: 0.1324 - accuracy: 0.9545 - val_loss: 0.0876 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 19/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9495
# Epoch 19: val_loss did not improve from 0.08759
# 215/215 [==============================] - 38s 175ms/step - loss: 0.1464 - accuracy: 0.9495 - val_loss: 0.0943 - val_accuracy: 0.9649 - lr: 5.0000e-06
# Epoch 20/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9495
# Epoch 20: val_loss improved from 0.08759 to 0.08492, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 39s 183ms/step - loss: 0.1404 - accuracy: 0.9495 - val_loss: 0.0849 - val_accuracy: 0.9605 - lr: 5.0000e-06
# Epoch 21/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9475
# Epoch 21: val_loss improved from 0.08492 to 0.08489, saving model to ../models\best_model4.h5
# 215/215 [==============================] - 40s 188ms/step - loss: 0.1486 - accuracy: 0.9475 - val_loss: 0.0849 - val_accuracy: 0.9649 - lr: 5.0000e-06
# Epoch 22/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9560
# Epoch 22: val_loss did not improve from 0.08489
# 215/215 [==============================] - 38s 178ms/step - loss: 0.1247 - accuracy: 0.9560 - val_loss: 0.0915 - val_accuracy: 0.9649 - lr: 5.0000e-06
# Epoch 23/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9571
# Epoch 23: val_loss did not improve from 0.08489
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 215/215 [==============================] - 38s 176ms/step - loss: 0.1313 - accuracy: 0.9571 - val_loss: 0.0972 - val_accuracy: 0.9693 - lr: 5.0000e-06
# Epoch 24/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9612
# Epoch 24: val_loss did not improve from 0.08489
# 215/215 [==============================] - 38s 177ms/step - loss: 0.1148 - accuracy: 0.9612 - val_loss: 0.0880 - val_accuracy: 0.9649 - lr: 2.5000e-06
# Epoch 25/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9528
# Epoch 25: val_loss did not improve from 0.08489
# 215/215 [==============================] - 38s 178ms/step - loss: 0.1297 - accuracy: 0.9528 - val_loss: 0.0909 - val_accuracy: 0.9649 - lr: 2.5000e-06
# Epoch 26/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9615
# Epoch 26: val_loss did not improve from 0.08489
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 215/215 [==============================] - 39s 180ms/step - loss: 0.1148 - accuracy: 0.9615 - val_loss: 0.0881 - val_accuracy: 0.9649 - lr: 2.5000e-06
# Epoch 27/30
# 215/215 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9641
# Epoch 27: val_loss did not improve from 0.08489
# Restoring model weights from the end of the best epoch: 21.
# 215/215 [==============================] - 40s 184ms/step - loss: 0.1028 - accuracy: 0.9641 - val_loss: 0.0858 - val_accuracy: 0.9605 - lr: 1.2500e-06
# Epoch 27: early stopping

# %%
# ==========================================
# STEP 8: Save final model & metadata
# ==========================================

# --- GABUNGKAN HISTORY (fase 1 + fase 2) ---
# agar grafik & statistik mencakup seluruh pelatihan
combined_history = {}
for key in history.history.keys():
    combined_history[key] = history.history[key] + history_finetune.history.get(key, [])

# --- Hitung rata-rata akurasi dari fase akhir (fine-tuning) ---
train_acc_avg = np.mean(history_finetune.history.get('accuracy', history.history.get('accuracy', [-1])))
val_acc_avg   = np.mean(history_finetune.history.get('val_accuracy', history.history.get('val_accuracy', [-1])))

train_acc_int = int(train_acc_avg * 100)
val_acc_int = int(val_acc_avg * 100)

# create versioned folder like before
pattern = re.compile(r"Model-RDC-(\d+).(\d+)")
existing_dirs = [d for d in os.listdir(MODEL_DIR) if os.path.isdir(os.path.join(MODEL_DIR, d))]
model_id = MODEL_ID
versions = []
for d in existing_dirs:
    m = pattern.match(d)
    if m and int(m.group(1)) == model_id:
        versions.append(int(m.group(2)))
next_version = max(versions) + 1 if versions else 1

# --- Buat folder penyimpanan baru ---
model_fname = f"Model-RDC-{model_id}.{next_version}"
save_dir = os.path.join(MODEL_DIR, model_fname)
os.makedirs(save_dir, exist_ok=True)

# --- Simpan model final (setelah fine-tuning) ---
final_model_path = os.path.join(save_dir, f"model.h5")
model.save(final_model_path)

# --- Simpan label kelas ---
labels = {v: k for k, v in train_generator.class_indices.items()}
with open(os.path.join(save_dir, "labels.json"), "w") as f:
    json.dump(labels, f, indent=4)

# --- Simpan ringkasan metadata model ---
summary = {
    "model_id": model_id,
    "version": next_version,
    "model_name": model_fname,
    "model_use": MODEL_NAME,
    "train_acc_avg": round(float(train_acc_avg) * 100, 2),
    "val_acc_avg": round(float(val_acc_avg) * 100, 2),
    "epochs_phase1": len(history.history.get('accuracy', [])),
    "epochs_phase2": len(history_finetune.history.get('accuracy', [])),
    "model_path": final_model_path
}
with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

def to_serializable(obj):
    """Konversi semua numpy type ke tipe Python biasa agar bisa di-dump ke JSON"""
    if isinstance(obj, (np.float32, np.float64)):
        return float(obj)
    if isinstance(obj, (np.int32, np.int64)):
        return int(obj)
    if isinstance(obj, (np.ndarray, list)):
        return [to_serializable(x) for x in obj]
    if isinstance(obj, dict):
        return {k: to_serializable(v) for k, v in obj.items()}
    return obj


# --- Simpan riwayat pelatihan (fase 1, fase 2, dan gabungan) ---
with open(os.path.join(save_dir, "history_phase1.json"), "w") as f:
    json.dump(to_serializable(history.history), f, indent=4)

with open(os.path.join(save_dir, "history_finetune.json"), "w") as f:
    json.dump(to_serializable(history_finetune.history), f, indent=4)

with open(os.path.join(save_dir, "history_combined.json"), "w") as f:
    json.dump(to_serializable(combined_history), f, indent=4)


print(f"📁 Semua file metadata dan history disimpan di: {save_dir}")
# Out:
# 📁 Semua file metadata dan history disimpan di: ../models\Model-RDC-4.1

# %%
# ==========================================
# STEP 9: Plot & save metrics (FINAL)
# ==========================================

# Gunakan combined_history dari STEP 8
acc      = combined_history.get('accuracy', [])
val_acc  = combined_history.get('val_accuracy', [])
loss     = combined_history.get('loss', [])
val_loss = combined_history.get('val_loss', [])

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

# --- Plot Accuracy ---
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Accuracy')
plt.plot(epochs_range, val_acc, label='Val Accuracy')
plt.title("Training & Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# --- Plot Loss ---
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()

# --- Simpan grafik ---
metrics_path = os.path.join(save_dir, "metrics.png")
plt.savefig(metrics_path)
plt.show()
plt.close()

print(f"📈 Grafik akurasi & loss disimpan di: {metrics_path}")
# Out:
# 📈 Grafik akurasi & loss disimpan di: ../models\Model-RDC-4.1\metrics.png

# %%
# ==========================================
# STEP 10: Evaluation (validation set)
# ==========================================
print("\n🚀 Evaluasi Model pada Validation Set...")

# --- Reset generator agar prediksi berurutan ---
val_generator.reset()

# --- Prediksi ---
y_pred = model.predict(val_generator, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

# --- Label kelas ---
class_labels = list(val_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Validation):")
report_val = classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true,
    y_pred_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_val_path = os.path.join(save_dir, "evaluation_val.json")
with open(eval_val_path, "w") as f:
    json.dump(report_val, f, indent=4)
print(f"✅ Laporan evaluasi validasi disimpan: {eval_val_path}")

# --- Confusion Matrix ---
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')

# --- Simpan confusion matrix ---
cm_val_path = os.path.join(save_dir, "confusion_matrix_val.png")
plt.tight_layout()
plt.savefig(cm_val_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix validasi disimpan di: {cm_val_path}")
# Out:
# 🚀 Evaluasi Model pada Validation Set...
#
# 📊 Classification Report (Validation):
#               precision    recall  f1-score   support
#
#         alur       0.67      0.80      0.73         5
#       lubang       0.96      0.99      0.97       116
#        retak       0.99      0.95      0.97        93
#  tidak_rusak       1.00      0.93      0.96        14
#
#     accuracy                           0.96       228
#    macro avg       0.90      0.92      0.91       228
# weighted avg       0.97      0.96      0.97       228
#
# ✅ Laporan evaluasi validasi disimpan: ../models\Model-RDC-4.1\evaluation_val.json
# 🧩 Confusion matrix validasi disimpan di: ../models\Model-RDC-4.1\confusion_matrix_val.png

# %%
# ==========================================
# STEP 11: Testing (test set)
# ==========================================
print("\n🚀 Evaluasi Model pada Test Set...")

# --- Reset generator ---
test_generator.reset()

# --- Evaluasi langsung ---
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"\n📈 Test Accuracy: {test_acc*100:.2f}%  |  Test Loss: {test_loss:.4f}")

# --- Prediksi ---
y_pred_test = model.predict(test_generator, verbose=0)
y_pred_test_classes = np.argmax(y_pred_test, axis=1)
y_true_test = test_generator.classes

# --- Label kelas ---
class_labels = list(test_generator.class_indices.keys())

# --- Classification Report ---
print("\n📊 Classification Report (Test):")
report_test = classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0,
    output_dict=True
)
print(classification_report(
    y_true_test,
    y_pred_test_classes,
    target_names=class_labels,
    zero_division=0
))

# --- Simpan laporan evaluasi ke JSON ---
eval_test_path = os.path.join(save_dir, "evaluation_test.json")
with open(eval_test_path, "w") as f:
    json.dump(report_test, f, indent=4)
print(f"✅ Laporan evaluasi testing disimpan: {eval_test_path}")

# --- Confusion Matrix ---
cm_test = confusion_matrix(y_true_test, y_pred_test_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Greens',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Test Set')

# --- Simpan confusion matrix ---
cm_test_path = os.path.join(save_dir, "confusion_matrix_test.png")
plt.tight_layout()
plt.savefig(cm_test_path)
plt.show()
plt.close()

print(f"🧩 Confusion matrix testing disimpan di: {cm_test_path}")

# --- Simpan ringkasan hasil test ke summary.json ---
summary["test_accuracy"] = round(float(test_acc) * 100, 2)
summary["test_loss"] = round(float(test_loss), 4)

with open(os.path.join(save_dir, "summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

print(f"📘 Summary diperbarui dengan hasil test: {os.path.join(save_dir, 'summary.json')}")
# Out:
# 🚀 Evaluasi Model pada Test Set...
#
# 📈 Test Accuracy: 98.62%  |  Test Loss: 0.0805
#
# 📊 Classification Report (Test):
#               precision    recall  f1-score   support
#
#         alur       0.75      1.00      0.86         6
#       lubang       1.00      1.00      1.00       112
#        retak       0.99      0.98      0.98        90
#  tidak_rusak       1.00      0.90      0.95        10
#
#     accuracy                           0.99       218
#    macro avg       0.93      0.97      0.95       218
# weighted avg       0.99      0.99      0.99       218
#
# ✅ Laporan evaluasi testing disimpan: ../models\Model-RDC-4.1\evaluation_test.json
# 🧩 Confusion matrix testing disimpan di: ../models\Model-RDC-4.1\confusion_matrix_test.png
# 📘 Summary diperbarui dengan hasil test: ../models\Model-RDC-4.1\summary.json
